# %%
import os, random, json, warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

# Tensorflow 관련 제거하고 Scikit-Learn RandomForest 추가
from sklearn.ensemble import RandomForestClassifier
import tensorflow as tf
from tensorflow.keras import layers, regularizers, models, optimizers, callbacks

# Optuna
import optuna
from optuna.integration import TFKerasPruningCallback
from sklearn.model_selection import StratifiedKFold
import gc
import xgboost as xgb
# =========================
# CONFIG
# =========================
SEED = 1
MODE = "STRICT_CAUSAL"
SPLIT_STRATEGY = "RANDOM_ROW"
POS_RATIO = 0.10
TARGET_TOTAL = 100_000

EPOCHS = 50           # 최종 재학습 epoch
VAL_FRAC = 0.15
TEST_FRAC = 0.15
TIME_HOLDOUT_TEST_WEEKS = 8
TOL = 0.0025

# ✅ Optuna(튜닝) 전용 설정
N_TRIALS = 10             # Optuna trial 수
EPOCHS_TUNE = 15         # 튜닝용 epoch (CV 안에서)
MAX_TUNE_SAMPLES = 30_000  # fold별 train에서 최대 이만큼만 사용

# 최종 평가용 threshold
OPERATING_THR = 0.5
DATA_DIR = "."
# 고정 시드
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED); np.random.seed(SEED);
rng = np.random.RandomState(SEED)

# 1. Base 데이터 (v0) 로드
path_v0 = os.path.join(DATA_DIR, "featured_v0.parquet")
print(f"[LOAD] Base: {path_v0}")
final_data = pd.read_parquet(path_v0)
print(f"   -> Base Shape: {final_data.shape}")

# 2. v1 ~ v4 순회하며 새로운 컬럼만 병합
versions = ["v1", "v2", "v3", "v4"]

for ver in versions:
    path_ver = os.path.join(DATA_DIR, f"featured_{ver}.parquet")
    if os.path.exists(path_ver):
        print(f"[MERGE] Checking {ver}...")
        temp_df = pd.read_parquet(path_ver)
        
        # v0(현재 final_data)에 없는 컬럼만 추출 (즉, 추가된 A, B, C, D 부분)
        new_cols = [c for c in temp_df.columns if c not in final_data.columns]
        
        if new_cols:
            # 인덱스 기준 병합 (axis=1). 행 순서가 동일하다고 가정합니다.
            # 만약 행 순서가 다르다면 merge(on='id')를 써야 하지만, 
            # 보통 FE 파이프라인 결과물은 순서가 같습니다.
            final_data = pd.concat([final_data, temp_df[new_cols]], axis=1)
            print(f"   -> Added {len(new_cols)} features from {ver} (ex: {new_cols[:3]}...)")
        else:
            print(f"   -> No new features in {ver}")
            
        # 메모리 정리
        del temp_df
        gc.collect()
    else:
        print(f"[WARN] File not found: {path_ver}")

print(f"\n[FINAL DATA] Total Shape: {final_data.shape}")
print("========================================")

# =========================
# 수동 metric + AUC 계산 함수
# =========================
def compute_roc_auc_manual(y_true, y_prob):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob, dtype=float)

    # NaN 제거
    mask = ~np.isnan(y_prob)
    y_true = y_true[mask]
    y_prob = y_prob[mask]

    n_pos = (y_true == 1).sum()
    n_neg = (y_true == 0).sum()
    if n_pos == 0 or n_neg == 0:
        return float("nan")

    # 확률 내림차순 정렬
    order = np.argsort(-y_prob)
    y_true_sorted = y_true[order]

    cum_pos = np.cumsum(y_true_sorted == 1)
    cum_neg = np.cumsum(y_true_sorted == 0)

    tpr = cum_pos / n_pos
    fpr = cum_neg / n_neg

    # 사다리꼴 적분
    auc = 0.0
    prev_fpr = 0.0
    prev_tpr = 0.0
    for i in range(len(y_true_sorted)):
        auc += (fpr[i] - prev_fpr) * (tpr[i] + prev_tpr) / 2.0
        prev_fpr = fpr[i]
        prev_tpr = tpr[i]

    return float(auc)


# =========================
# 수동 metric + AUC + AIC/BIC 계산 함수
# =========================
def compute_aic_bic_manual(y_true, y_prob, n_features):
    """
    Log-Likelihood를 기반으로 AIC, BIC 계산
    """
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob, dtype=float)
    
    # Log(0) 방지를 위한 clipping (epsilon)
    eps = 1e-15
    y_prob = np.clip(y_prob, eps, 1 - eps)
    
    # Log Likelihood 계산
    # L = sum( y*log(p) + (1-y)*log(1-p) )
    log_likelihood = np.sum(y_true * np.log(y_prob) + (1 - y_true) * np.log(1 - y_prob))
    
    n = len(y_true)
    k = n_features
    
    aic = 2 * k - 2 * log_likelihood
    bic = k * np.log(n) - 2 * log_likelihood
    
    return float(aic), float(bic), float(log_likelihood)

def compute_classification_metrics(y_true, y_prob, thr=0.8, n_features=None):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob, dtype=float)
    y_pred = (y_prob >= thr).astype(int)

    tp = int(((y_true == 1) & (y_pred == 1)).sum())
    tn = int(((y_true == 0) & (y_pred == 0)).sum())
    fp = int(((y_true == 0) & (y_pred == 1)).sum())
    fn = int(((y_true == 1) & (y_pred == 0)).sum())

    n = len(y_true)
    eps = 1e-9

    accuracy    = (tp + tn) / (n + eps)
    precision   = tp / (tp + fp + eps)
    recall      = tp / (tp + fn + eps)
    specificity = tn / (tn + fp + eps)
    f1          = 2 * precision * recall / (precision + recall + eps)

    roc_auc = compute_roc_auc_manual(y_true, y_prob)

    metrics = {
        "accuracy":       float(accuracy),
        "precision":      float(precision),
        "recall":         float(recall),
        "specificity":    float(specificity),
        "f1":             float(f1),
        "roc_auc":        float(roc_auc),
        "n_eval":         int(n),
        "pos_rate_eval":  float(y_true.mean()),
    }

    # [추가됨] n_features가 들어오면 AIC/BIC 계산
    if n_features is not None:
        aic, bic, ll = compute_aic_bic_manual(y_true, y_prob, n_features)
        metrics["aic"] = aic
        metrics["bic"] = bic
        metrics["log_likelihood"] = ll
        metrics["n_features"] = int(n_features)

    cm = (tn, fp, fn, tp)
    return metrics, cm


# =========================
# SPLIT
# =========================
def brief(name, df):
    if df is None or len(df) == 0:
        print(f"[{name}] n=0"); return
    pos = int(df["is_purchased"].sum())
    n = len(df); rate = pos / max(n, 1)
    print(f"[{name}] n={n:,}  pos={pos:,}  rate={rate:.6f}")
def brief(name, df):
    if df is None or len(df) == 0:
        print(f"[{name}] n=0"); return
    pos = int(df["is_purchased"].sum())
    n = len(df); rate = pos / max(n, 1)
    print(f"[{name}] n={n:,}  pos={pos:,}  rate={rate:.6f}")

def check_ratio(df, target_ratio=0.10, tol=TOL, name="dataset"):
    if len(df) == 0: return
    r = float(df["is_purchased"].mean())
    ok = abs(r - target_ratio) <= tol
    print(f"[check {name}] pos_rate={r:.6f}  target={target_ratio:.2f}  diff={r-target_ratio:+.6f}  {'OK' if ok else 'WARN'}")

def stratified_fixed_sample(df, target_col="is_purchased", total_n=100_000, pos_ratio=0.10, seed=SEED):
    n_pos_k = int(round(total_n * pos_ratio))
    n_neg_k = total_n - n_pos_k
    pos = df[df[target_col] == 1]
    neg = df[df[target_col] == 0]
    pos_s = pos.sample(n=min(n_pos_k, len(pos)), random_state=seed, replace=False)
    neg_s = neg.sample(n=min(n_neg_k, len(neg)), random_state=seed, replace=False)
    out = pd.concat([pos_s, neg_s], axis=0).sample(frac=1.0, random_state=seed).reset_index(drop=True)
    return out

def split_random_row_simple(df, val_frac=VAL_FRAC, test_frac=TEST_FRAC, seed=SEED):
    rng_local = np.random.RandomState(seed)
    N = len(df)
    idx = np.arange(N); rng_local.shuffle(idx)
    n_test = int(round(N * test_frac))
    n_val  = int(round(N * val_frac))
    te_idx = idx[:n_test]
    va_idx = idx[n_test:n_test+n_val]
    tr_idx = idx[n_test+n_val:]
    te = df.iloc[te_idx].reset_index(drop=True)
    va = df.iloc[va_idx].reset_index(drop=True)
    tr = df.iloc[tr_idx].reset_index(drop=True)
    return tr, va, te

dataset = final_data.sample(frac=1.0, random_state=SEED).reset_index(drop=True)
brief("dataset(raw)", dataset)
if TARGET_TOTAL and len(dataset) > TARGET_TOTAL:
    dataset = stratified_fixed_sample(dataset, target_col="is_purchased",
                                      total_n=TARGET_TOTAL, pos_ratio=POS_RATIO, seed=SEED)
brief("dataset(after 100K sampling)", dataset)
check_ratio(dataset, POS_RATIO, name="dataset(100K)")

if SPLIT_STRATEGY == "RANDOM_ROW":
    train_df, val_df, test_df = split_random_row_simple(dataset)
elif SPLIT_STRATEGY == "TIME_HOLDOUT":
    train_df, val_df, test_df = split_time_holdout(dataset)
else:
    train_df, val_df, test_df = split_user_disjoint(dataset)
    
TARGET = "is_purchased"

# =======================================================
# 1. Base Features (v0) - 총 41개
# : 캠페인, 채널, 플랫폼, 기본 이력 통계 등 가장 기초적인 정보
# =======================================================
cols_v0 = [
    'avg_campaign_duration', 'avg_time_since_complaint', 'avg_time_since_first_purchase',
    'avg_time_since_last_click', 'avg_time_since_last_open', 'avg_time_since_unsubscribe',
    'camp_campaign_typebulk', 'camp_campaign_typetransactional', 'camp_campaign_typetrigger',
    'camp_channelemail', 'camp_channelmobile_push', 'camp_channelmultichannel', 'camp_channelsms',
    'camp_topicevent', 'camp_topichappy.birthday', 'camp_topicleave.review',
    'camp_topicoffer.after.purchase', 'camp_topicother', 'camp_topicsale.out',
    'channel_email', 'channel_mobile_push', 'channel_web_push',
    'email_provider_gmail.com', 'email_provider_mail.ru', 'email_provider_other',
    'is_holiday',
    'message_type_bulk', 'message_type_transactional', 'message_type_trigger',
    'platform.', 'platform.desktop', 'platform.phablet', 'platform.smartphone', 'platform.tablet',
    'prev_is_clicked', 'prev_is_complained', 'prev_is_opened', 'prev_is_unsubscribed',
    'total_campaigns', 'total_messages', 'total_purchases'
]

# =======================================================
# 2. Add-on Features (v1) - 총 3개
# : 구매 주기 및 행동 위험도 (Hazard/Refraction)
# =======================================================
cols_v1 = [
    'days_since_last_purchase',
    'feat_rtb_hazard',
    'feat_postbuy_refrac'
]

# =======================================================
# 3. Add-on Features (v2) - 총 6개
# : 캘린더 효과(주말/월초) 및 시간대 이동(Shift)
# =======================================================
cols_v2 = [
    'cal_is_weekend',
    'cal_week_of_month',
    'feat_dow_shift',
    'feat_eoq_bump',
    'feat_hour_shift',
    'feat_payday_bump'
]

# =======================================================
# 4. Add-on Features (v3) - 총 9개
# : 유저 피로도(Fatigue) 및 최근 30일 반응률(Context)
# =======================================================
cols_v3 = [
    'ctx_tc_open_rate_30d',
    'feat_fatigue',
    'feat_last_any_hours',
    'feat_last_email_hours',
    'feat_last_mobile_push_hours',
    'u_cadence_std_30d',
    'u_click_rate_30d',
    'u_open_cnt_30d',
    'u_open_rate_30d'
]

# =======================================================
# 5. Add-on Features (v4) - 총 5개
# : 토픽 신선도 및 행동 경로 유사성 (Sequence/Path)
# =======================================================
cols_v4 = [
    'feat_like_last_success',
    'feat_path_align',
    'feat_topic_novelty',
    'topic_N7',
    'topic_t_since_hours'
]

def get_feat_cols(df):
    """
    데이터프레임에서 학습에 사용할 최종 수치형 변수 리스트를 반환합니다.
    Target과 제외 리스트(ID, Leakage, Collinear)를 필터링합니다.
    """
    # 1. 모든 수치형 컬럼 추출
    num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    
    # 2. 제외 대상 필터링 (Target + Drop List)
    final_cols = list(cols_v0)# + cols_v1)# + cols_v2 + cols_v3 + cols_v4)
    
    # 3. 정렬 (모델 재현성을 위해 이름순 정렬)
    return sorted(final_cols)

# -------------------------------------------------------
# 실행 및 결과 확인
# -------------------------------------------------------
# train_df는 이미 로드되어 있다고 가정
feat_cols = get_feat_cols(train_df)
n_feat = len(feat_cols)

# LSTM용 3차원 변환(reshape)을 제거하고 2차원 그대로 사용합니다.
def prepare_data_mlp(df, feature_columns):
    X = df[feature_columns].fillna(0).astype(np.float32).to_numpy()
    Y = df[TARGET].fillna(0).astype(np.int32).to_numpy()
    # LSTM의 reshape((N, F, 1)) 과정을 삭제
    return X, Y

# 이후 기존 코드 실행
Xtr, Ytr = prepare_data_mlp(train_df, feat_cols)
Xva, Yva = prepare_data_mlp(val_df, feat_cols)
Xte, Yte = prepare_data_mlp(test_df, feat_cols)

print("=== Data Shapes (MLP) ===")
print(f"Train: X={Xtr.shape}, Y={Ytr.shape}")
print(f"Val  : X={Xva.shape}, Y={Yva.shape}")
print(f"Test : X={Xte.shape}, Y={Yte.shape}")


# =========================
# [변경 3] RETRAIN WITH BEST PARAMS
# =========================
print("\n[Final] Retraining MLP with best hyperparameters...")
best_params_mlp = {
      "lr": 0.0008237189558335285,
      "batch_size": 64,
      "optimizer": "rmsprop",
      "n_layers": 3,
      "dropout_rate": 0.49554443556259786,
      "l2": 0.0017558886158773755,
      "activation": "gelu",
      "units_l0": 128,
      "units_l1": 256,
      "units_l2": 96
    }

tf.keras.backend.clear_session()

activation = best_params_mlp["activation"]
opt_name   = best_params_mlp["optimizer"]
lr         = best_params_mlp["lr"]

def build_final_optimizer():
    if opt_name == "adam":
        return optimizers.Adam(lr)
    elif opt_name == "rmsprop":
        return optimizers.RMSprop(lr)
    else:
        return optimizers.SGD(
            lr,
            momentum=best_params_mlp.get("momentum", 0.0)
        )

model = models.Sequential()
model.add(layers.Input(shape=(n_feat,)))

for i in range(best_params_mlp["n_layers"]):
    model.add(
        layers.Dense(
            best_params_mlp.get(f"units_l{i}", 64),
            activation=activation,
            kernel_regularizer=regularizers.l2(best_params_mlp["l2"])
        )
    )
    model.add(layers.Dropout(best_params_mlp["dropout_rate"]))

model.add(layers.Dense(1, activation="sigmoid"))

model.compile(
    optimizer=build_final_optimizer(),
    loss="binary_crossentropy"
)

es = callbacks.EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)
rlr = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2, min_lr=1e-6)

history = model.fit(
    Xtr, Ytr,
    validation_data=(Xva, Yva),
    epochs=EPOCHS,
    batch_size=best_params_mlp["batch_size"],
    verbose=2,
    callbacks=[es, rlr]
)


# =========================
# FINAL EVALUATION (수동 metric)
# =========================
y_prob = model.predict(Xte, verbose=0).ravel()
y_true = Yte
n_features_used = Xte.shape[1]
final_metrics, (tn, fp, fn, tp) = compute_classification_metrics(
    y_true, y_prob, thr=OPERATING_THR, n_features=n_features_used
)

final_metrics.update({
    "mode": MODE,
    "split": SPLIT_STRATEGY,
    "best_params": best_params_mlp
})

print(json.dumps({"metrics": final_metrics}, indent=2))
print("confusion_matrix [tn fp fn tp]:", tn, fp, fn, tp)
# Out:
# [LOAD] Base: ./featured_v0.parquet
#    -> Base Shape: (433520, 62)
# [MERGE] Checking v1...
#    -> Added 3 features from v1 (ex: ['days_since_last_purchase', 'feat_rtb_hazard', 'feat_postbuy_refrac']...)
# [MERGE] Checking v2...
#    -> Added 7 features from v2 (ex: ['feat_hour_shift', 'feat_dow_shift', 'feat_payday_bump']...)
# [MERGE] Checking v3...
#    -> Added 45 features from v3 (ex: ['is_hard_bounced', 'hard_bounced_at', 'is_soft_bounced']...)
# [MERGE] Checking v4...
#    -> Added 7 features from v4 (ex: ['tn_sent_local', 'feat_topic_novelty', 'topic_N7']...)
#
# [FINAL DATA] Total Shape: (579551, 124)
# ========================================
# [dataset(raw)] n=579,551  pos=43,352  rate=0.074803
# [dataset(after 100K sampling)] n=100,000  pos=10,000  rate=0.100000
# [check dataset(100K)] pos_rate=0.100000  target=0.10  diff=+0.000000  OK
# === Data Shapes (MLP) ===
# Train: X=(70000, 41), Y=(70000,)
# Val  : X=(15000, 41), Y=(15000,)
# Test : X=(15000, 41), Y=(15000,)
#
# [Final] Retraining MLP with best hyperparameters...
# Epoch 1/50
# 1094/1094 - 6s - 6ms/step - loss: 2.3075 - val_loss: 0.3664 - learning_rate: 8.2372e-04
# Epoch 2/50
# 1094/1094 - 2s - 2ms/step - loss: 0.6012 - val_loss: 0.2391 - learning_rate: 8.2372e-04
# Epoch 3/50
# 1094/1094 - 2s - 2ms/step - loss: 0.3188 - val_loss: 0.3050 - learning_rate: 8.2372e-04
# Epoch 4/50
# 1094/1094 - 2s - 2ms/step - loss: 0.2652 - val_loss: 0.2096 - learning_rate: 8.2372e-04
# Epoch 5/50
# 1094/1094 - 2s - 2ms/step - loss: 0.2011 - val_loss: 0.1796 - learning_rate: 8.2372e-04
# Epoch 6/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1934 - val_loss: 0.2044 - learning_rate: 8.2372e-04
# Epoch 7/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1869 - val_loss: 0.1772 - learning_rate: 8.2372e-04
# Epoch 8/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1828 - val_loss: 0.1798 - learning_rate: 8.2372e-04
# Epoch 9/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1832 - val_loss: 0.1784 - learning_rate: 8.2372e-04
# Epoch 10/50
# 1094/1094 - 2s - 1ms/step - loss: 0.1743 - val_loss: 0.1697 - learning_rate: 4.1186e-04
# Epoch 11/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1715 - val_loss: 0.1700 - learning_rate: 4.1186e-04
# Epoch 12/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1717 - val_loss: 0.1659 - learning_rate: 4.1186e-04
# Epoch 13/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1719 - val_loss: 0.1747 - learning_rate: 4.1186e-04
# Epoch 14/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1724 - val_loss: 0.1739 - learning_rate: 4.1186e-04
# Epoch 15/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1687 - val_loss: 0.1673 - learning_rate: 2.0593e-04
# Epoch 16/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1667 - val_loss: 0.1720 - learning_rate: 2.0593e-04
# Epoch 17/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1659 - val_loss: 0.1664 - learning_rate: 1.0296e-04
# {
#   "metrics": {
#     "accuracy": 0.9421333333332705,
#     "precision": 0.8727477477467649,
#     "recall": 0.5065359477120872,
#     "specificity": 0.9916109873792879,
#     "f1": 0.6410256405603582,
#     "roc_auc": 0.9555068392117817,
#     "n_eval": 15000,
#     "pos_rate_eval": 0.102,
#     "aic": 4234.259685552029,
#     "bic": 4546.507710235487,
#     "log_likelihood": -2076.1298427760144,
#     "n_features": 41,
#     "mode": "STRICT_CAUSAL",
#     "split": "RANDOM_ROW",
#     "best_params": {
#       "lr": 0.0008237189558335285,
#       "batch_size": 64,
#       "optimizer": "rmsprop",
#       "n_layers": 3,
#       "dropout_rate": 0.49554443556259786,
#       "l2": 0.0017558886158773755,
#       "activation": "gelu",
#       "units_l0": 128,
#       "units_l1": 256,
#       "units_l2": 96
#     }
#   }
# }
# confusion_matrix [tn fp fn tp]: 13357 113 755 775

# %%
import os, random, json, warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

# Tensorflow 관련 제거하고 Scikit-Learn RandomForest 추가
from sklearn.ensemble import RandomForestClassifier
import tensorflow as tf
from tensorflow.keras import layers, regularizers, models, optimizers, callbacks

# Optuna
import optuna
from optuna.integration import TFKerasPruningCallback
from sklearn.model_selection import StratifiedKFold
import gc
import xgboost as xgb
# =========================
# CONFIG
# =========================
SEED = 1
MODE = "STRICT_CAUSAL"
SPLIT_STRATEGY = "RANDOM_ROW"
POS_RATIO = 0.10
TARGET_TOTAL = 100_000

EPOCHS = 50           # 최종 재학습 epoch
VAL_FRAC = 0.15
TEST_FRAC = 0.15
TIME_HOLDOUT_TEST_WEEKS = 8
TOL = 0.0025

# ✅ Optuna(튜닝) 전용 설정
N_TRIALS = 10             # Optuna trial 수
EPOCHS_TUNE = 15         # 튜닝용 epoch (CV 안에서)
MAX_TUNE_SAMPLES = 30_000  # fold별 train에서 최대 이만큼만 사용

# 최종 평가용 threshold
OPERATING_THR = 0.5
DATA_DIR = "."
# 고정 시드
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED); np.random.seed(SEED);
rng = np.random.RandomState(SEED)

# 1. Base 데이터 (v0) 로드
path_v0 = os.path.join(DATA_DIR, "featured_v0.parquet")
print(f"[LOAD] Base: {path_v0}")
final_data = pd.read_parquet(path_v0)
print(f"   -> Base Shape: {final_data.shape}")

# 2. v1 ~ v4 순회하며 새로운 컬럼만 병합
versions = ["v1", "v2", "v3", "v4"]

for ver in versions:
    path_ver = os.path.join(DATA_DIR, f"featured_{ver}.parquet")
    if os.path.exists(path_ver):
        print(f"[MERGE] Checking {ver}...")
        temp_df = pd.read_parquet(path_ver)
        
        # v0(현재 final_data)에 없는 컬럼만 추출 (즉, 추가된 A, B, C, D 부분)
        new_cols = [c for c in temp_df.columns if c not in final_data.columns]
        
        if new_cols:
            # 인덱스 기준 병합 (axis=1). 행 순서가 동일하다고 가정합니다.
            # 만약 행 순서가 다르다면 merge(on='id')를 써야 하지만, 
            # 보통 FE 파이프라인 결과물은 순서가 같습니다.
            final_data = pd.concat([final_data, temp_df[new_cols]], axis=1)
            print(f"   -> Added {len(new_cols)} features from {ver} (ex: {new_cols[:3]}...)")
        else:
            print(f"   -> No new features in {ver}")
            
        # 메모리 정리
        del temp_df
        gc.collect()
    else:
        print(f"[WARN] File not found: {path_ver}")

print(f"\n[FINAL DATA] Total Shape: {final_data.shape}")
print("========================================")

# =========================
# 수동 metric + AUC 계산 함수
# =========================
def compute_roc_auc_manual(y_true, y_prob):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob, dtype=float)

    # NaN 제거
    mask = ~np.isnan(y_prob)
    y_true = y_true[mask]
    y_prob = y_prob[mask]

    n_pos = (y_true == 1).sum()
    n_neg = (y_true == 0).sum()
    if n_pos == 0 or n_neg == 0:
        return float("nan")

    # 확률 내림차순 정렬
    order = np.argsort(-y_prob)
    y_true_sorted = y_true[order]

    cum_pos = np.cumsum(y_true_sorted == 1)
    cum_neg = np.cumsum(y_true_sorted == 0)

    tpr = cum_pos / n_pos
    fpr = cum_neg / n_neg

    # 사다리꼴 적분
    auc = 0.0
    prev_fpr = 0.0
    prev_tpr = 0.0
    for i in range(len(y_true_sorted)):
        auc += (fpr[i] - prev_fpr) * (tpr[i] + prev_tpr) / 2.0
        prev_fpr = fpr[i]
        prev_tpr = tpr[i]

    return float(auc)


# =========================
# 수동 metric + AUC + AIC/BIC 계산 함수
# =========================
def compute_aic_bic_manual(y_true, y_prob, n_features):
    """
    Log-Likelihood를 기반으로 AIC, BIC 계산
    """
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob, dtype=float)
    
    # Log(0) 방지를 위한 clipping (epsilon)
    eps = 1e-15
    y_prob = np.clip(y_prob, eps, 1 - eps)
    
    # Log Likelihood 계산
    # L = sum( y*log(p) + (1-y)*log(1-p) )
    log_likelihood = np.sum(y_true * np.log(y_prob) + (1 - y_true) * np.log(1 - y_prob))
    
    n = len(y_true)
    k = n_features
    
    aic = 2 * k - 2 * log_likelihood
    bic = k * np.log(n) - 2 * log_likelihood
    
    return float(aic), float(bic), float(log_likelihood)

def compute_classification_metrics(y_true, y_prob, thr=0.8, n_features=None):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob, dtype=float)
    y_pred = (y_prob >= thr).astype(int)

    tp = int(((y_true == 1) & (y_pred == 1)).sum())
    tn = int(((y_true == 0) & (y_pred == 0)).sum())
    fp = int(((y_true == 0) & (y_pred == 1)).sum())
    fn = int(((y_true == 1) & (y_pred == 0)).sum())

    n = len(y_true)
    eps = 1e-9

    accuracy    = (tp + tn) / (n + eps)
    precision   = tp / (tp + fp + eps)
    recall      = tp / (tp + fn + eps)
    specificity = tn / (tn + fp + eps)
    f1          = 2 * precision * recall / (precision + recall + eps)

    roc_auc = compute_roc_auc_manual(y_true, y_prob)

    metrics = {
        "accuracy":       float(accuracy),
        "precision":      float(precision),
        "recall":         float(recall),
        "specificity":    float(specificity),
        "f1":             float(f1),
        "roc_auc":        float(roc_auc),
        "n_eval":         int(n),
        "pos_rate_eval":  float(y_true.mean()),
    }

    # [추가됨] n_features가 들어오면 AIC/BIC 계산
    if n_features is not None:
        aic, bic, ll = compute_aic_bic_manual(y_true, y_prob, n_features)
        metrics["aic"] = aic
        metrics["bic"] = bic
        metrics["log_likelihood"] = ll
        metrics["n_features"] = int(n_features)

    cm = (tn, fp, fn, tp)
    return metrics, cm


# =========================
# SPLIT
# =========================
def brief(name, df):
    if df is None or len(df) == 0:
        print(f"[{name}] n=0"); return
    pos = int(df["is_purchased"].sum())
    n = len(df); rate = pos / max(n, 1)
    print(f"[{name}] n={n:,}  pos={pos:,}  rate={rate:.6f}")
def brief(name, df):
    if df is None or len(df) == 0:
        print(f"[{name}] n=0"); return
    pos = int(df["is_purchased"].sum())
    n = len(df); rate = pos / max(n, 1)
    print(f"[{name}] n={n:,}  pos={pos:,}  rate={rate:.6f}")

def check_ratio(df, target_ratio=0.10, tol=TOL, name="dataset"):
    if len(df) == 0: return
    r = float(df["is_purchased"].mean())
    ok = abs(r - target_ratio) <= tol
    print(f"[check {name}] pos_rate={r:.6f}  target={target_ratio:.2f}  diff={r-target_ratio:+.6f}  {'OK' if ok else 'WARN'}")

def stratified_fixed_sample(df, target_col="is_purchased", total_n=100_000, pos_ratio=0.10, seed=SEED):
    n_pos_k = int(round(total_n * pos_ratio))
    n_neg_k = total_n - n_pos_k
    pos = df[df[target_col] == 1]
    neg = df[df[target_col] == 0]
    pos_s = pos.sample(n=min(n_pos_k, len(pos)), random_state=seed, replace=False)
    neg_s = neg.sample(n=min(n_neg_k, len(neg)), random_state=seed, replace=False)
    out = pd.concat([pos_s, neg_s], axis=0).sample(frac=1.0, random_state=seed).reset_index(drop=True)
    return out

def split_random_row_simple(df, val_frac=VAL_FRAC, test_frac=TEST_FRAC, seed=SEED):
    rng_local = np.random.RandomState(seed)
    N = len(df)
    idx = np.arange(N); rng_local.shuffle(idx)
    n_test = int(round(N * test_frac))
    n_val  = int(round(N * val_frac))
    te_idx = idx[:n_test]
    va_idx = idx[n_test:n_test+n_val]
    tr_idx = idx[n_test+n_val:]
    te = df.iloc[te_idx].reset_index(drop=True)
    va = df.iloc[va_idx].reset_index(drop=True)
    tr = df.iloc[tr_idx].reset_index(drop=True)
    return tr, va, te

dataset = final_data.sample(frac=1.0, random_state=SEED).reset_index(drop=True)
brief("dataset(raw)", dataset)
if TARGET_TOTAL and len(dataset) > TARGET_TOTAL:
    dataset = stratified_fixed_sample(dataset, target_col="is_purchased",
                                      total_n=TARGET_TOTAL, pos_ratio=POS_RATIO, seed=SEED)
brief("dataset(after 100K sampling)", dataset)
check_ratio(dataset, POS_RATIO, name="dataset(100K)")

if SPLIT_STRATEGY == "RANDOM_ROW":
    train_df, val_df, test_df = split_random_row_simple(dataset)
elif SPLIT_STRATEGY == "TIME_HOLDOUT":
    train_df, val_df, test_df = split_time_holdout(dataset)
else:
    train_df, val_df, test_df = split_user_disjoint(dataset)
    
TARGET = "is_purchased"

# =======================================================
# 1. Base Features (v0) - 총 41개
# : 캠페인, 채널, 플랫폼, 기본 이력 통계 등 가장 기초적인 정보
# =======================================================
cols_v0 = [
    'avg_campaign_duration', 'avg_time_since_complaint', 'avg_time_since_first_purchase',
    'avg_time_since_last_click', 'avg_time_since_last_open', 'avg_time_since_unsubscribe',
    'camp_campaign_typebulk', 'camp_campaign_typetransactional', 'camp_campaign_typetrigger',
    'camp_channelemail', 'camp_channelmobile_push', 'camp_channelmultichannel', 'camp_channelsms',
    'camp_topicevent', 'camp_topichappy.birthday', 'camp_topicleave.review',
    'camp_topicoffer.after.purchase', 'camp_topicother', 'camp_topicsale.out',
    'channel_email', 'channel_mobile_push', 'channel_web_push',
    'email_provider_gmail.com', 'email_provider_mail.ru', 'email_provider_other',
    'is_holiday',
    'message_type_bulk', 'message_type_transactional', 'message_type_trigger',
    'platform.', 'platform.desktop', 'platform.phablet', 'platform.smartphone', 'platform.tablet',
    'prev_is_clicked', 'prev_is_complained', 'prev_is_opened', 'prev_is_unsubscribed',
    'total_campaigns', 'total_messages', 'total_purchases'
]

# =======================================================
# 2. Add-on Features (v1) - 총 3개
# : 구매 주기 및 행동 위험도 (Hazard/Refraction)
# =======================================================
cols_v1 = [
    'days_since_last_purchase',
    'feat_rtb_hazard',
    'feat_postbuy_refrac'
]

# =======================================================
# 3. Add-on Features (v2) - 총 6개
# : 캘린더 효과(주말/월초) 및 시간대 이동(Shift)
# =======================================================
cols_v2 = [
    'cal_is_weekend',
    'cal_week_of_month',
    'feat_dow_shift',
    'feat_eoq_bump',
    'feat_hour_shift',
    'feat_payday_bump'
]

# =======================================================
# 4. Add-on Features (v3) - 총 9개
# : 유저 피로도(Fatigue) 및 최근 30일 반응률(Context)
# =======================================================
cols_v3 = [
    'ctx_tc_open_rate_30d',
    'feat_fatigue',
    'feat_last_any_hours',
    'feat_last_email_hours',
    'feat_last_mobile_push_hours',
    'u_cadence_std_30d',
    'u_click_rate_30d',
    'u_open_cnt_30d',
    'u_open_rate_30d'
]

# =======================================================
# 5. Add-on Features (v4) - 총 5개
# : 토픽 신선도 및 행동 경로 유사성 (Sequence/Path)
# =======================================================
cols_v4 = [
    'feat_like_last_success',
    'feat_path_align',
    'feat_topic_novelty',
    'topic_N7',
    'topic_t_since_hours'
]

def get_feat_cols(df):
    """
    데이터프레임에서 학습에 사용할 최종 수치형 변수 리스트를 반환합니다.
    Target과 제외 리스트(ID, Leakage, Collinear)를 필터링합니다.
    """
    # 1. 모든 수치형 컬럼 추출
    num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    
    # 2. 제외 대상 필터링 (Target + Drop List)
    final_cols = list(cols_v0 + cols_v1)# + cols_v2 + cols_v3 + cols_v4)
    
    # 3. 정렬 (모델 재현성을 위해 이름순 정렬)
    return sorted(final_cols)

# -------------------------------------------------------
# 실행 및 결과 확인
# -------------------------------------------------------
# train_df는 이미 로드되어 있다고 가정
feat_cols = get_feat_cols(train_df)
n_feat = len(feat_cols)

# LSTM용 3차원 변환(reshape)을 제거하고 2차원 그대로 사용합니다.
def prepare_data_mlp(df, feature_columns):
    X = df[feature_columns].fillna(0).astype(np.float32).to_numpy()
    Y = df[TARGET].fillna(0).astype(np.int32).to_numpy()
    # LSTM의 reshape((N, F, 1)) 과정을 삭제
    return X, Y

# 이후 기존 코드 실행
Xtr, Ytr = prepare_data_mlp(train_df, feat_cols)
Xva, Yva = prepare_data_mlp(val_df, feat_cols)
Xte, Yte = prepare_data_mlp(test_df, feat_cols)

print("=== Data Shapes (MLP) ===")
print(f"Train: X={Xtr.shape}, Y={Ytr.shape}")
print(f"Val  : X={Xva.shape}, Y={Yva.shape}")
print(f"Test : X={Xte.shape}, Y={Yte.shape}")


# =========================
# [변경 3] RETRAIN WITH BEST PARAMS
# =========================
print("\n[Final] Retraining MLP with best hyperparameters...")
best_params_mlp = {
      "lr": 0.0008237189558335285,
      "batch_size": 64,
      "optimizer": "rmsprop",
      "n_layers": 3,
      "dropout_rate": 0.49554443556259786,
      "l2": 0.0017558886158773755,
      "activation": "gelu",
      "units_l0": 128,
      "units_l1": 256,
      "units_l2": 96
    }

tf.keras.backend.clear_session()

activation = best_params_mlp["activation"]
opt_name   = best_params_mlp["optimizer"]
lr         = best_params_mlp["lr"]

def build_final_optimizer():
    if opt_name == "adam":
        return optimizers.Adam(lr)
    elif opt_name == "rmsprop":
        return optimizers.RMSprop(lr)
    else:
        return optimizers.SGD(
            lr,
            momentum=best_params_mlp.get("momentum", 0.0)
        )

model = models.Sequential()
model.add(layers.Input(shape=(n_feat,)))

for i in range(best_params_mlp["n_layers"]):
    model.add(
        layers.Dense(
            best_params_mlp.get(f"units_l{i}", 64),
            activation=activation,
            kernel_regularizer=regularizers.l2(best_params_mlp["l2"])
        )
    )
    model.add(layers.Dropout(best_params_mlp["dropout_rate"]))

model.add(layers.Dense(1, activation="sigmoid"))

model.compile(
    optimizer=build_final_optimizer(),
    loss="binary_crossentropy"
)

es = callbacks.EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)
rlr = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2, min_lr=1e-6)

history = model.fit(
    Xtr, Ytr,
    validation_data=(Xva, Yva),
    epochs=EPOCHS,
    batch_size=best_params_mlp["batch_size"],
    verbose=2,
    callbacks=[es, rlr]
)


# =========================
# FINAL EVALUATION (수동 metric)
# =========================
y_prob = model.predict(Xte, verbose=0).ravel()
y_true = Yte
n_features_used = Xte.shape[1]
final_metrics, (tn, fp, fn, tp) = compute_classification_metrics(
    y_true, y_prob, thr=OPERATING_THR, n_features=n_features_used
)

final_metrics.update({
    "mode": MODE,
    "split": SPLIT_STRATEGY,
    "best_params": best_params_mlp
})

print(json.dumps({"metrics": final_metrics}, indent=2))
print("confusion_matrix [tn fp fn tp]:", tn, fp, fn, tp)
# Out:
# [LOAD] Base: ./featured_v0.parquet
#    -> Base Shape: (433520, 62)
# [MERGE] Checking v1...
#    -> Added 3 features from v1 (ex: ['days_since_last_purchase', 'feat_rtb_hazard', 'feat_postbuy_refrac']...)
# [MERGE] Checking v2...
#    -> Added 7 features from v2 (ex: ['feat_hour_shift', 'feat_dow_shift', 'feat_payday_bump']...)
# [MERGE] Checking v3...
#    -> Added 45 features from v3 (ex: ['is_hard_bounced', 'hard_bounced_at', 'is_soft_bounced']...)
# [MERGE] Checking v4...
#    -> Added 7 features from v4 (ex: ['tn_sent_local', 'feat_topic_novelty', 'topic_N7']...)
#
# [FINAL DATA] Total Shape: (579551, 124)
# ========================================
# [dataset(raw)] n=579,551  pos=43,352  rate=0.074803
# [dataset(after 100K sampling)] n=100,000  pos=10,000  rate=0.100000
# [check dataset(100K)] pos_rate=0.100000  target=0.10  diff=+0.000000  OK
# === Data Shapes (MLP) ===
# Train: X=(70000, 44), Y=(70000,)
# Val  : X=(15000, 44), Y=(15000,)
# Test : X=(15000, 44), Y=(15000,)
#
# [Final] Retraining MLP with best hyperparameters...
# Epoch 1/50
# 1094/1094 - 6s - 5ms/step - loss: 2.3292 - val_loss: 0.4103 - learning_rate: 8.2372e-04
# Epoch 2/50
# 1094/1094 - 2s - 2ms/step - loss: 0.5753 - val_loss: 0.3171 - learning_rate: 8.2372e-04
# Epoch 3/50
# 1094/1094 - 2s - 2ms/step - loss: 0.3442 - val_loss: 0.2047 - learning_rate: 8.2372e-04
# Epoch 4/50
# 1094/1094 - 2s - 1ms/step - loss: 0.2517 - val_loss: 0.1957 - learning_rate: 8.2372e-04
# Epoch 5/50
# 1094/1094 - 2s - 2ms/step - loss: 0.2181 - val_loss: 0.2190 - learning_rate: 8.2372e-04
# Epoch 6/50
# 1094/1094 - 2s - 2ms/step - loss: 0.2030 - val_loss: 0.1928 - learning_rate: 8.2372e-04
# Epoch 7/50
# 1094/1094 - 2s - 2ms/step - loss: 0.2089 - val_loss: 0.1881 - learning_rate: 8.2372e-04
# Epoch 8/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1949 - val_loss: 0.1861 - learning_rate: 8.2372e-04
# Epoch 9/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1968 - val_loss: 0.1867 - learning_rate: 8.2372e-04
# Epoch 10/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1955 - val_loss: 0.1909 - learning_rate: 8.2372e-04
# Epoch 11/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1814 - val_loss: 0.1757 - learning_rate: 4.1186e-04
# Epoch 12/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1788 - val_loss: 0.1751 - learning_rate: 4.1186e-04
# Epoch 13/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1784 - val_loss: 0.1767 - learning_rate: 4.1186e-04
# Epoch 14/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1787 - val_loss: 0.1842 - learning_rate: 4.1186e-04
# Epoch 15/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1749 - val_loss: 0.1711 - learning_rate: 2.0593e-04
# Epoch 16/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1723 - val_loss: 0.1662 - learning_rate: 2.0593e-04
# Epoch 17/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1715 - val_loss: 0.1729 - learning_rate: 2.0593e-04
# Epoch 18/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1699 - val_loss: 0.1701 - learning_rate: 2.0593e-04
# Epoch 19/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1673 - val_loss: 0.1653 - learning_rate: 1.0296e-04
# Epoch 20/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1659 - val_loss: 0.1708 - learning_rate: 1.0296e-04
# Epoch 21/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1661 - val_loss: 0.1673 - learning_rate: 1.0296e-04
# Epoch 22/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1637 - val_loss: 0.1640 - learning_rate: 5.1482e-05
# Epoch 23/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1632 - val_loss: 0.1653 - learning_rate: 5.1482e-05
# Epoch 24/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1640 - val_loss: 0.1657 - learning_rate: 5.1482e-05
# Epoch 25/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1610 - val_loss: 0.1661 - learning_rate: 2.5741e-05
# Epoch 26/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1621 - val_loss: 0.1631 - learning_rate: 2.5741e-05
# Epoch 27/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1621 - val_loss: 0.1628 - learning_rate: 2.5741e-05
# Epoch 28/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1609 - val_loss: 0.1638 - learning_rate: 2.5741e-05
# Epoch 29/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1608 - val_loss: 0.1635 - learning_rate: 2.5741e-05
# Epoch 30/50
# 1094/1094 - 2s - 1ms/step - loss: 0.1609 - val_loss: 0.1622 - learning_rate: 1.2871e-05
# Epoch 31/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1613 - val_loss: 0.1627 - learning_rate: 1.2871e-05
# Epoch 32/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1612 - val_loss: 0.1631 - learning_rate: 1.2871e-05
# Epoch 33/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1594 - val_loss: 0.1629 - learning_rate: 6.4353e-06
# Epoch 34/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1614 - val_loss: 0.1626 - learning_rate: 6.4353e-06
# Epoch 35/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1603 - val_loss: 0.1634 - learning_rate: 3.2177e-06
# {
#   "metrics": {
#     "accuracy": 0.9430666666666038,
#     "precision": 0.8498964803303831,
#     "recall": 0.5366013071891917,
#     "specificity": 0.9892353377876029,
#     "f1": 0.6578525636275663,
#     "roc_auc": 0.9587369657092715,
#     "n_eval": 15000,
#     "pos_rate_eval": 0.102,
#     "aic": 4147.069093444089,
#     "bic": 4482.164534567801,
#     "log_likelihood": -2029.5345467220445,
#     "n_features": 44,
#     "mode": "STRICT_CAUSAL",
#     "split": "RANDOM_ROW",
#     "best_params": {
#       "lr": 0.0008237189558335285,
#       "batch_size": 64,
#       "optimizer": "rmsprop",
#       "n_layers": 3,
#       "dropout_rate": 0.49554443556259786,
#       "l2": 0.0017558886158773755,
#       "activation": "gelu",
#       "units_l0": 128,
#       "units_l1": 256,
#       "units_l2": 96
#     }
#   }
# }
# confusion_matrix [tn fp fn tp]: 13325 145 709 821

# %%
import os, random, json, warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

# Tensorflow 관련 제거하고 Scikit-Learn RandomForest 추가
from sklearn.ensemble import RandomForestClassifier
import tensorflow as tf
from tensorflow.keras import layers, regularizers, models, optimizers, callbacks

# Optuna
import optuna
from optuna.integration import TFKerasPruningCallback
from sklearn.model_selection import StratifiedKFold
import gc
import xgboost as xgb
# =========================
# CONFIG
# =========================
SEED = 1
MODE = "STRICT_CAUSAL"
SPLIT_STRATEGY = "RANDOM_ROW"
POS_RATIO = 0.10
TARGET_TOTAL = 100_000

EPOCHS = 50           # 최종 재학습 epoch
VAL_FRAC = 0.15
TEST_FRAC = 0.15
TIME_HOLDOUT_TEST_WEEKS = 8
TOL = 0.0025

# ✅ Optuna(튜닝) 전용 설정
N_TRIALS = 10             # Optuna trial 수
EPOCHS_TUNE = 15         # 튜닝용 epoch (CV 안에서)
MAX_TUNE_SAMPLES = 30_000  # fold별 train에서 최대 이만큼만 사용

# 최종 평가용 threshold
OPERATING_THR = 0.5
DATA_DIR = "."
# 고정 시드
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED); np.random.seed(SEED);
rng = np.random.RandomState(SEED)

# 1. Base 데이터 (v0) 로드
path_v0 = os.path.join(DATA_DIR, "featured_v0.parquet")
print(f"[LOAD] Base: {path_v0}")
final_data = pd.read_parquet(path_v0)
print(f"   -> Base Shape: {final_data.shape}")

# 2. v1 ~ v4 순회하며 새로운 컬럼만 병합
versions = ["v1", "v2", "v3", "v4"]

for ver in versions:
    path_ver = os.path.join(DATA_DIR, f"featured_{ver}.parquet")
    if os.path.exists(path_ver):
        print(f"[MERGE] Checking {ver}...")
        temp_df = pd.read_parquet(path_ver)
        
        # v0(현재 final_data)에 없는 컬럼만 추출 (즉, 추가된 A, B, C, D 부분)
        new_cols = [c for c in temp_df.columns if c not in final_data.columns]
        
        if new_cols:
            # 인덱스 기준 병합 (axis=1). 행 순서가 동일하다고 가정합니다.
            # 만약 행 순서가 다르다면 merge(on='id')를 써야 하지만, 
            # 보통 FE 파이프라인 결과물은 순서가 같습니다.
            final_data = pd.concat([final_data, temp_df[new_cols]], axis=1)
            print(f"   -> Added {len(new_cols)} features from {ver} (ex: {new_cols[:3]}...)")
        else:
            print(f"   -> No new features in {ver}")
            
        # 메모리 정리
        del temp_df
        gc.collect()
    else:
        print(f"[WARN] File not found: {path_ver}")

print(f"\n[FINAL DATA] Total Shape: {final_data.shape}")
print("========================================")

# =========================
# 수동 metric + AUC 계산 함수
# =========================
def compute_roc_auc_manual(y_true, y_prob):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob, dtype=float)

    # NaN 제거
    mask = ~np.isnan(y_prob)
    y_true = y_true[mask]
    y_prob = y_prob[mask]

    n_pos = (y_true == 1).sum()
    n_neg = (y_true == 0).sum()
    if n_pos == 0 or n_neg == 0:
        return float("nan")

    # 확률 내림차순 정렬
    order = np.argsort(-y_prob)
    y_true_sorted = y_true[order]

    cum_pos = np.cumsum(y_true_sorted == 1)
    cum_neg = np.cumsum(y_true_sorted == 0)

    tpr = cum_pos / n_pos
    fpr = cum_neg / n_neg

    # 사다리꼴 적분
    auc = 0.0
    prev_fpr = 0.0
    prev_tpr = 0.0
    for i in range(len(y_true_sorted)):
        auc += (fpr[i] - prev_fpr) * (tpr[i] + prev_tpr) / 2.0
        prev_fpr = fpr[i]
        prev_tpr = tpr[i]

    return float(auc)


# =========================
# 수동 metric + AUC + AIC/BIC 계산 함수
# =========================
def compute_aic_bic_manual(y_true, y_prob, n_features):
    """
    Log-Likelihood를 기반으로 AIC, BIC 계산
    """
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob, dtype=float)
    
    # Log(0) 방지를 위한 clipping (epsilon)
    eps = 1e-15
    y_prob = np.clip(y_prob, eps, 1 - eps)
    
    # Log Likelihood 계산
    # L = sum( y*log(p) + (1-y)*log(1-p) )
    log_likelihood = np.sum(y_true * np.log(y_prob) + (1 - y_true) * np.log(1 - y_prob))
    
    n = len(y_true)
    k = n_features
    
    aic = 2 * k - 2 * log_likelihood
    bic = k * np.log(n) - 2 * log_likelihood
    
    return float(aic), float(bic), float(log_likelihood)

def compute_classification_metrics(y_true, y_prob, thr=0.8, n_features=None):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob, dtype=float)
    y_pred = (y_prob >= thr).astype(int)

    tp = int(((y_true == 1) & (y_pred == 1)).sum())
    tn = int(((y_true == 0) & (y_pred == 0)).sum())
    fp = int(((y_true == 0) & (y_pred == 1)).sum())
    fn = int(((y_true == 1) & (y_pred == 0)).sum())

    n = len(y_true)
    eps = 1e-9

    accuracy    = (tp + tn) / (n + eps)
    precision   = tp / (tp + fp + eps)
    recall      = tp / (tp + fn + eps)
    specificity = tn / (tn + fp + eps)
    f1          = 2 * precision * recall / (precision + recall + eps)

    roc_auc = compute_roc_auc_manual(y_true, y_prob)

    metrics = {
        "accuracy":       float(accuracy),
        "precision":      float(precision),
        "recall":         float(recall),
        "specificity":    float(specificity),
        "f1":             float(f1),
        "roc_auc":        float(roc_auc),
        "n_eval":         int(n),
        "pos_rate_eval":  float(y_true.mean()),
    }

    # [추가됨] n_features가 들어오면 AIC/BIC 계산
    if n_features is not None:
        aic, bic, ll = compute_aic_bic_manual(y_true, y_prob, n_features)
        metrics["aic"] = aic
        metrics["bic"] = bic
        metrics["log_likelihood"] = ll
        metrics["n_features"] = int(n_features)

    cm = (tn, fp, fn, tp)
    return metrics, cm


# =========================
# SPLIT
# =========================
def brief(name, df):
    if df is None or len(df) == 0:
        print(f"[{name}] n=0"); return
    pos = int(df["is_purchased"].sum())
    n = len(df); rate = pos / max(n, 1)
    print(f"[{name}] n={n:,}  pos={pos:,}  rate={rate:.6f}")
def brief(name, df):
    if df is None or len(df) == 0:
        print(f"[{name}] n=0"); return
    pos = int(df["is_purchased"].sum())
    n = len(df); rate = pos / max(n, 1)
    print(f"[{name}] n={n:,}  pos={pos:,}  rate={rate:.6f}")

def check_ratio(df, target_ratio=0.10, tol=TOL, name="dataset"):
    if len(df) == 0: return
    r = float(df["is_purchased"].mean())
    ok = abs(r - target_ratio) <= tol
    print(f"[check {name}] pos_rate={r:.6f}  target={target_ratio:.2f}  diff={r-target_ratio:+.6f}  {'OK' if ok else 'WARN'}")

def stratified_fixed_sample(df, target_col="is_purchased", total_n=100_000, pos_ratio=0.10, seed=SEED):
    n_pos_k = int(round(total_n * pos_ratio))
    n_neg_k = total_n - n_pos_k
    pos = df[df[target_col] == 1]
    neg = df[df[target_col] == 0]
    pos_s = pos.sample(n=min(n_pos_k, len(pos)), random_state=seed, replace=False)
    neg_s = neg.sample(n=min(n_neg_k, len(neg)), random_state=seed, replace=False)
    out = pd.concat([pos_s, neg_s], axis=0).sample(frac=1.0, random_state=seed).reset_index(drop=True)
    return out

def split_random_row_simple(df, val_frac=VAL_FRAC, test_frac=TEST_FRAC, seed=SEED):
    rng_local = np.random.RandomState(seed)
    N = len(df)
    idx = np.arange(N); rng_local.shuffle(idx)
    n_test = int(round(N * test_frac))
    n_val  = int(round(N * val_frac))
    te_idx = idx[:n_test]
    va_idx = idx[n_test:n_test+n_val]
    tr_idx = idx[n_test+n_val:]
    te = df.iloc[te_idx].reset_index(drop=True)
    va = df.iloc[va_idx].reset_index(drop=True)
    tr = df.iloc[tr_idx].reset_index(drop=True)
    return tr, va, te

dataset = final_data.sample(frac=1.0, random_state=SEED).reset_index(drop=True)
brief("dataset(raw)", dataset)
if TARGET_TOTAL and len(dataset) > TARGET_TOTAL:
    dataset = stratified_fixed_sample(dataset, target_col="is_purchased",
                                      total_n=TARGET_TOTAL, pos_ratio=POS_RATIO, seed=SEED)
brief("dataset(after 100K sampling)", dataset)
check_ratio(dataset, POS_RATIO, name="dataset(100K)")

if SPLIT_STRATEGY == "RANDOM_ROW":
    train_df, val_df, test_df = split_random_row_simple(dataset)
elif SPLIT_STRATEGY == "TIME_HOLDOUT":
    train_df, val_df, test_df = split_time_holdout(dataset)
else:
    train_df, val_df, test_df = split_user_disjoint(dataset)
    
TARGET = "is_purchased"

# =======================================================
# 1. Base Features (v0) - 총 41개
# : 캠페인, 채널, 플랫폼, 기본 이력 통계 등 가장 기초적인 정보
# =======================================================
cols_v0 = [
    'avg_campaign_duration', 'avg_time_since_complaint', 'avg_time_since_first_purchase',
    'avg_time_since_last_click', 'avg_time_since_last_open', 'avg_time_since_unsubscribe',
    'camp_campaign_typebulk', 'camp_campaign_typetransactional', 'camp_campaign_typetrigger',
    'camp_channelemail', 'camp_channelmobile_push', 'camp_channelmultichannel', 'camp_channelsms',
    'camp_topicevent', 'camp_topichappy.birthday', 'camp_topicleave.review',
    'camp_topicoffer.after.purchase', 'camp_topicother', 'camp_topicsale.out',
    'channel_email', 'channel_mobile_push', 'channel_web_push',
    'email_provider_gmail.com', 'email_provider_mail.ru', 'email_provider_other',
    'is_holiday',
    'message_type_bulk', 'message_type_transactional', 'message_type_trigger',
    'platform.', 'platform.desktop', 'platform.phablet', 'platform.smartphone', 'platform.tablet',
    'prev_is_clicked', 'prev_is_complained', 'prev_is_opened', 'prev_is_unsubscribed',
    'total_campaigns', 'total_messages', 'total_purchases'
]

# =======================================================
# 2. Add-on Features (v1) - 총 3개
# : 구매 주기 및 행동 위험도 (Hazard/Refraction)
# =======================================================
cols_v1 = [
    'days_since_last_purchase',
    'feat_rtb_hazard',
    'feat_postbuy_refrac'
]

# =======================================================
# 3. Add-on Features (v2) - 총 6개
# : 캘린더 효과(주말/월초) 및 시간대 이동(Shift)
# =======================================================
cols_v2 = [
    'cal_is_weekend',
    'cal_week_of_month',
    'feat_dow_shift',
    'feat_eoq_bump',
    'feat_hour_shift',
    'feat_payday_bump'
]

# =======================================================
# 4. Add-on Features (v3) - 총 9개
# : 유저 피로도(Fatigue) 및 최근 30일 반응률(Context)
# =======================================================
cols_v3 = [
    'ctx_tc_open_rate_30d',
    'feat_fatigue',
    'feat_last_any_hours',
    'feat_last_email_hours',
    'feat_last_mobile_push_hours',
    'u_cadence_std_30d',
    'u_click_rate_30d',
    'u_open_cnt_30d',
    'u_open_rate_30d'
]

# =======================================================
# 5. Add-on Features (v4) - 총 5개
# : 토픽 신선도 및 행동 경로 유사성 (Sequence/Path)
# =======================================================
cols_v4 = [
    'feat_like_last_success',
    'feat_path_align',
    'feat_topic_novelty',
    'topic_N7',
    'topic_t_since_hours'
]

def get_feat_cols(df):
    """
    데이터프레임에서 학습에 사용할 최종 수치형 변수 리스트를 반환합니다.
    Target과 제외 리스트(ID, Leakage, Collinear)를 필터링합니다.
    """
    # 1. 모든 수치형 컬럼 추출
    num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    
    # 2. 제외 대상 필터링 (Target + Drop List)
    final_cols = list(cols_v0 + cols_v2)# + cols_v2 + cols_v3 + cols_v4)
    
    # 3. 정렬 (모델 재현성을 위해 이름순 정렬)
    return sorted(final_cols)

# -------------------------------------------------------
# 실행 및 결과 확인
# -------------------------------------------------------
# train_df는 이미 로드되어 있다고 가정
feat_cols = get_feat_cols(train_df)
n_feat = len(feat_cols)

# LSTM용 3차원 변환(reshape)을 제거하고 2차원 그대로 사용합니다.
def prepare_data_mlp(df, feature_columns):
    X = df[feature_columns].fillna(0).astype(np.float32).to_numpy()
    Y = df[TARGET].fillna(0).astype(np.int32).to_numpy()
    # LSTM의 reshape((N, F, 1)) 과정을 삭제
    return X, Y

# 이후 기존 코드 실행
Xtr, Ytr = prepare_data_mlp(train_df, feat_cols)
Xva, Yva = prepare_data_mlp(val_df, feat_cols)
Xte, Yte = prepare_data_mlp(test_df, feat_cols)

print("=== Data Shapes (MLP) ===")
print(f"Train: X={Xtr.shape}, Y={Ytr.shape}")
print(f"Val  : X={Xva.shape}, Y={Yva.shape}")
print(f"Test : X={Xte.shape}, Y={Yte.shape}")


# =========================
# [변경 3] RETRAIN WITH BEST PARAMS
# =========================
print("\n[Final] Retraining MLP with best hyperparameters...")
best_params_mlp = {
      "lr": 0.0008237189558335285,
      "batch_size": 64,
      "optimizer": "rmsprop",
      "n_layers": 3,
      "dropout_rate": 0.49554443556259786,
      "l2": 0.0017558886158773755,
      "activation": "gelu",
      "units_l0": 128,
      "units_l1": 256,
      "units_l2": 96
    }

tf.keras.backend.clear_session()

activation = best_params_mlp["activation"]
opt_name   = best_params_mlp["optimizer"]
lr         = best_params_mlp["lr"]

def build_final_optimizer():
    if opt_name == "adam":
        return optimizers.Adam(lr)
    elif opt_name == "rmsprop":
        return optimizers.RMSprop(lr)
    else:
        return optimizers.SGD(
            lr,
            momentum=best_params_mlp.get("momentum", 0.0)
        )

model = models.Sequential()
model.add(layers.Input(shape=(n_feat,)))

for i in range(best_params_mlp["n_layers"]):
    model.add(
        layers.Dense(
            best_params_mlp.get(f"units_l{i}", 64),
            activation=activation,
            kernel_regularizer=regularizers.l2(best_params_mlp["l2"])
        )
    )
    model.add(layers.Dropout(best_params_mlp["dropout_rate"]))

model.add(layers.Dense(1, activation="sigmoid"))

model.compile(
    optimizer=build_final_optimizer(),
    loss="binary_crossentropy"
)

es = callbacks.EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)
rlr = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2, min_lr=1e-6)

history = model.fit(
    Xtr, Ytr,
    validation_data=(Xva, Yva),
    epochs=EPOCHS,
    batch_size=best_params_mlp["batch_size"],
    verbose=2,
    callbacks=[es, rlr]
)


# =========================
# FINAL EVALUATION (수동 metric)
# =========================
y_prob = model.predict(Xte, verbose=0).ravel()
y_true = Yte
n_features_used = Xte.shape[1]
final_metrics, (tn, fp, fn, tp) = compute_classification_metrics(
    y_true, y_prob, thr=OPERATING_THR, n_features=n_features_used
)

final_metrics.update({
    "mode": MODE,
    "split": SPLIT_STRATEGY,
    "best_params": best_params_mlp
})

print(json.dumps({"metrics": final_metrics}, indent=2))
print("confusion_matrix [tn fp fn tp]:", tn, fp, fn, tp)
# Out:
# [LOAD] Base: ./featured_v0.parquet
#    -> Base Shape: (433520, 62)
# [MERGE] Checking v1...
#    -> Added 3 features from v1 (ex: ['days_since_last_purchase', 'feat_rtb_hazard', 'feat_postbuy_refrac']...)
# [MERGE] Checking v2...
#    -> Added 7 features from v2 (ex: ['feat_hour_shift', 'feat_dow_shift', 'feat_payday_bump']...)
# [MERGE] Checking v3...
#    -> Added 45 features from v3 (ex: ['is_hard_bounced', 'hard_bounced_at', 'is_soft_bounced']...)
# [MERGE] Checking v4...
#    -> Added 7 features from v4 (ex: ['tn_sent_local', 'feat_topic_novelty', 'topic_N7']...)
#
# [FINAL DATA] Total Shape: (579551, 124)
# ========================================
# [dataset(raw)] n=579,551  pos=43,352  rate=0.074803
# [dataset(after 100K sampling)] n=100,000  pos=10,000  rate=0.100000
# [check dataset(100K)] pos_rate=0.100000  target=0.10  diff=+0.000000  OK
# === Data Shapes (MLP) ===
# Train: X=(70000, 47), Y=(70000,)
# Val  : X=(15000, 47), Y=(15000,)
# Test : X=(15000, 47), Y=(15000,)
#
# [Final] Retraining MLP with best hyperparameters...
# Epoch 1/50
# 1094/1094 - 6s - 6ms/step - loss: 2.2920 - val_loss: 0.3889 - learning_rate: 8.2372e-04
# Epoch 2/50
# 1094/1094 - 2s - 2ms/step - loss: 0.5443 - val_loss: 0.2516 - learning_rate: 8.2372e-04
# Epoch 3/50
# 1094/1094 - 2s - 2ms/step - loss: 0.3277 - val_loss: 0.2648 - learning_rate: 8.2372e-04
# Epoch 4/50
# 1094/1094 - 2s - 2ms/step - loss: 0.2601 - val_loss: 0.1865 - learning_rate: 8.2372e-04
# Epoch 5/50
# 1094/1094 - 2s - 2ms/step - loss: 0.2089 - val_loss: 0.2012 - learning_rate: 8.2372e-04
# Epoch 6/50
# 1094/1094 - 2s - 2ms/step - loss: 0.2104 - val_loss: 0.1772 - learning_rate: 8.2372e-04
# Epoch 7/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1938 - val_loss: 0.2160 - learning_rate: 8.2372e-04
# Epoch 8/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1951 - val_loss: 0.1850 - learning_rate: 8.2372e-04
# Epoch 9/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1765 - val_loss: 0.1721 - learning_rate: 4.1186e-04
# Epoch 10/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1772 - val_loss: 0.1690 - learning_rate: 4.1186e-04
# Epoch 11/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1741 - val_loss: 0.1807 - learning_rate: 4.1186e-04
# Epoch 12/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1743 - val_loss: 0.1684 - learning_rate: 4.1186e-04
# Epoch 13/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1743 - val_loss: 0.1729 - learning_rate: 4.1186e-04
# Epoch 14/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1722 - val_loss: 0.1713 - learning_rate: 4.1186e-04
# Epoch 15/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1681 - val_loss: 0.1649 - learning_rate: 2.0593e-04
# Epoch 16/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1664 - val_loss: 0.1711 - learning_rate: 2.0593e-04
# Epoch 17/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1654 - val_loss: 0.1741 - learning_rate: 2.0593e-04
# Epoch 18/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1628 - val_loss: 0.1615 - learning_rate: 1.0296e-04
# Epoch 19/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1623 - val_loss: 0.1618 - learning_rate: 1.0296e-04
# Epoch 20/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1617 - val_loss: 0.1605 - learning_rate: 1.0296e-04
# Epoch 21/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1627 - val_loss: 0.1610 - learning_rate: 1.0296e-04
# Epoch 22/50
# 1094/1094 - 2s - 1ms/step - loss: 0.1624 - val_loss: 0.1615 - learning_rate: 1.0296e-04
# Epoch 23/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1599 - val_loss: 0.1641 - learning_rate: 5.1482e-05
# Epoch 24/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1598 - val_loss: 0.1614 - learning_rate: 5.1482e-05
# Epoch 25/50
# 1094/1094 - 2s - 1ms/step - loss: 0.1595 - val_loss: 0.1600 - learning_rate: 2.5741e-05
# Epoch 26/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1598 - val_loss: 0.1607 - learning_rate: 2.5741e-05
# Epoch 27/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1594 - val_loss: 0.1607 - learning_rate: 2.5741e-05
# Epoch 28/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1585 - val_loss: 0.1596 - learning_rate: 1.2871e-05
# Epoch 29/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1582 - val_loss: 0.1590 - learning_rate: 1.2871e-05
# Epoch 30/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1579 - val_loss: 0.1592 - learning_rate: 1.2871e-05
# Epoch 31/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1571 - val_loss: 0.1598 - learning_rate: 1.2871e-05
# Epoch 32/50
# 1094/1094 - 2s - 1ms/step - loss: 0.1578 - val_loss: 0.1601 - learning_rate: 6.4353e-06
# Epoch 33/50
# 1094/1094 - 2s - 1ms/step - loss: 0.1579 - val_loss: 0.1590 - learning_rate: 6.4353e-06
# Epoch 34/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1576 - val_loss: 0.1594 - learning_rate: 3.2177e-06
# {
#   "metrics": {
#     "accuracy": 0.9441333333332703,
#     "precision": 0.8552361396295121,
#     "recall": 0.5444444444440886,
#     "specificity": 0.9895322939865635,
#     "f1": 0.6653354627829063,
#     "roc_auc": 0.9600607983850695,
#     "n_eval": 15000,
#     "pos_rate_eval": 0.102,
#     "aic": 4114.893425408372,
#     "bic": 4472.836282972336,
#     "log_likelihood": -2010.4467127041862,
#     "n_features": 47,
#     "mode": "STRICT_CAUSAL",
#     "split": "RANDOM_ROW",
#     "best_params": {
#       "lr": 0.0008237189558335285,
#       "batch_size": 64,
#       "optimizer": "rmsprop",
#       "n_layers": 3,
#       "dropout_rate": 0.49554443556259786,
#       "l2": 0.0017558886158773755,
#       "activation": "gelu",
#       "units_l0": 128,
#       "units_l1": 256,
#       "units_l2": 96
#     }
#   }
# }
# confusion_matrix [tn fp fn tp]: 13329 141 697 833

# %%
import os, random, json, warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

# Tensorflow 관련 제거하고 Scikit-Learn RandomForest 추가
from sklearn.ensemble import RandomForestClassifier
import tensorflow as tf
from tensorflow.keras import layers, regularizers, models, optimizers, callbacks

# Optuna
import optuna
from optuna.integration import TFKerasPruningCallback
from sklearn.model_selection import StratifiedKFold
import gc
import xgboost as xgb
# =========================
# CONFIG
# =========================
SEED = 1
MODE = "STRICT_CAUSAL"
SPLIT_STRATEGY = "RANDOM_ROW"
POS_RATIO = 0.10
TARGET_TOTAL = 100_000

EPOCHS = 50           # 최종 재학습 epoch
VAL_FRAC = 0.15
TEST_FRAC = 0.15
TIME_HOLDOUT_TEST_WEEKS = 8
TOL = 0.0025

# ✅ Optuna(튜닝) 전용 설정
N_TRIALS = 10             # Optuna trial 수
EPOCHS_TUNE = 15         # 튜닝용 epoch (CV 안에서)
MAX_TUNE_SAMPLES = 30_000  # fold별 train에서 최대 이만큼만 사용

# 최종 평가용 threshold
OPERATING_THR = 0.5
DATA_DIR = "."
# 고정 시드
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED); np.random.seed(SEED);
rng = np.random.RandomState(SEED)

# 1. Base 데이터 (v0) 로드
path_v0 = os.path.join(DATA_DIR, "featured_all.parquet")
print(f"[LOAD] Base: {path_v0}")
final_data = pd.read_parquet(path_v0)

print(f"\n[FINAL DATA] Total Shape: {final_data.shape}")
print("========================================")

# =========================
# 수동 metric + AUC 계산 함수
# =========================
def compute_roc_auc_manual(y_true, y_prob):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob, dtype=float)

    # NaN 제거
    mask = ~np.isnan(y_prob)
    y_true = y_true[mask]
    y_prob = y_prob[mask]

    n_pos = (y_true == 1).sum()
    n_neg = (y_true == 0).sum()
    if n_pos == 0 or n_neg == 0:
        return float("nan")

    # 확률 내림차순 정렬
    order = np.argsort(-y_prob)
    y_true_sorted = y_true[order]

    cum_pos = np.cumsum(y_true_sorted == 1)
    cum_neg = np.cumsum(y_true_sorted == 0)

    tpr = cum_pos / n_pos
    fpr = cum_neg / n_neg

    # 사다리꼴 적분
    auc = 0.0
    prev_fpr = 0.0
    prev_tpr = 0.0
    for i in range(len(y_true_sorted)):
        auc += (fpr[i] - prev_fpr) * (tpr[i] + prev_tpr) / 2.0
        prev_fpr = fpr[i]
        prev_tpr = tpr[i]

    return float(auc)


# =========================
# 수동 metric + AUC + AIC/BIC 계산 함수
# =========================
def compute_aic_bic_manual(y_true, y_prob, n_features):
    """
    Log-Likelihood를 기반으로 AIC, BIC 계산
    """
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob, dtype=float)
    
    # Log(0) 방지를 위한 clipping (epsilon)
    eps = 1e-15
    y_prob = np.clip(y_prob, eps, 1 - eps)
    
    # Log Likelihood 계산
    # L = sum( y*log(p) + (1-y)*log(1-p) )
    log_likelihood = np.sum(y_true * np.log(y_prob) + (1 - y_true) * np.log(1 - y_prob))
    
    n = len(y_true)
    k = n_features
    
    aic = 2 * k - 2 * log_likelihood
    bic = k * np.log(n) - 2 * log_likelihood
    
    return float(aic), float(bic), float(log_likelihood)

def compute_classification_metrics(y_true, y_prob, thr=0.8, n_features=None):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob, dtype=float)
    y_pred = (y_prob >= thr).astype(int)

    tp = int(((y_true == 1) & (y_pred == 1)).sum())
    tn = int(((y_true == 0) & (y_pred == 0)).sum())
    fp = int(((y_true == 0) & (y_pred == 1)).sum())
    fn = int(((y_true == 1) & (y_pred == 0)).sum())

    n = len(y_true)
    eps = 1e-9

    accuracy    = (tp + tn) / (n + eps)
    precision   = tp / (tp + fp + eps)
    recall      = tp / (tp + fn + eps)
    specificity = tn / (tn + fp + eps)
    f1          = 2 * precision * recall / (precision + recall + eps)

    roc_auc = compute_roc_auc_manual(y_true, y_prob)

    metrics = {
        "accuracy":       float(accuracy),
        "precision":      float(precision),
        "recall":         float(recall),
        "specificity":    float(specificity),
        "f1":             float(f1),
        "roc_auc":        float(roc_auc),
        "n_eval":         int(n),
        "pos_rate_eval":  float(y_true.mean()),
    }

    # [추가됨] n_features가 들어오면 AIC/BIC 계산
    if n_features is not None:
        aic, bic, ll = compute_aic_bic_manual(y_true, y_prob, n_features)
        metrics["aic"] = aic
        metrics["bic"] = bic
        metrics["log_likelihood"] = ll
        metrics["n_features"] = int(n_features)

    cm = (tn, fp, fn, tp)
    return metrics, cm


# =========================
# SPLIT
# =========================
def brief(name, df):
    if df is None or len(df) == 0:
        print(f"[{name}] n=0"); return
    pos = int(df["is_purchased"].sum())
    n = len(df); rate = pos / max(n, 1)
    print(f"[{name}] n={n:,}  pos={pos:,}  rate={rate:.6f}")
def brief(name, df):
    if df is None or len(df) == 0:
        print(f"[{name}] n=0"); return
    pos = int(df["is_purchased"].sum())
    n = len(df); rate = pos / max(n, 1)
    print(f"[{name}] n={n:,}  pos={pos:,}  rate={rate:.6f}")

def check_ratio(df, target_ratio=0.10, tol=TOL, name="dataset"):
    if len(df) == 0: return
    r = float(df["is_purchased"].mean())
    ok = abs(r - target_ratio) <= tol
    print(f"[check {name}] pos_rate={r:.6f}  target={target_ratio:.2f}  diff={r-target_ratio:+.6f}  {'OK' if ok else 'WARN'}")

def stratified_fixed_sample(df, target_col="is_purchased", total_n=100_000, pos_ratio=0.10, seed=SEED):
    n_pos_k = int(round(total_n * pos_ratio))
    n_neg_k = total_n - n_pos_k
    pos = df[df[target_col] == 1]
    neg = df[df[target_col] == 0]
    pos_s = pos.sample(n=min(n_pos_k, len(pos)), random_state=seed, replace=False)
    neg_s = neg.sample(n=min(n_neg_k, len(neg)), random_state=seed, replace=False)
    out = pd.concat([pos_s, neg_s], axis=0).sample(frac=1.0, random_state=seed).reset_index(drop=True)
    return out

def split_random_row_simple(df, val_frac=VAL_FRAC, test_frac=TEST_FRAC, seed=SEED):
    rng_local = np.random.RandomState(seed)
    N = len(df)
    idx = np.arange(N); rng_local.shuffle(idx)
    n_test = int(round(N * test_frac))
    n_val  = int(round(N * val_frac))
    te_idx = idx[:n_test]
    va_idx = idx[n_test:n_test+n_val]
    tr_idx = idx[n_test+n_val:]
    te = df.iloc[te_idx].reset_index(drop=True)
    va = df.iloc[va_idx].reset_index(drop=True)
    tr = df.iloc[tr_idx].reset_index(drop=True)
    return tr, va, te

dataset = final_data.sample(frac=1.0, random_state=SEED).reset_index(drop=True)
brief("dataset(raw)", dataset)
if TARGET_TOTAL and len(dataset) > TARGET_TOTAL:
    dataset = stratified_fixed_sample(dataset, target_col="is_purchased",
                                      total_n=TARGET_TOTAL, pos_ratio=POS_RATIO, seed=SEED)
brief("dataset(after 100K sampling)", dataset)
check_ratio(dataset, POS_RATIO, name="dataset(100K)")

if SPLIT_STRATEGY == "RANDOM_ROW":
    train_df, val_df, test_df = split_random_row_simple(dataset)
elif SPLIT_STRATEGY == "TIME_HOLDOUT":
    train_df, val_df, test_df = split_time_holdout(dataset)
else:
    train_df, val_df, test_df = split_user_disjoint(dataset)
    
TARGET = "is_purchased"

# =======================================================
# 1. Base Features (v0) - 총 41개
# : 캠페인, 채널, 플랫폼, 기본 이력 통계 등 가장 기초적인 정보
# =======================================================
cols_v0 = [
    'avg_campaign_duration', 'avg_time_since_complaint', 'avg_time_since_first_purchase',
    'avg_time_since_last_click', 'avg_time_since_last_open', 'avg_time_since_unsubscribe',
    'camp_campaign_typebulk', 'camp_campaign_typetransactional', 'camp_campaign_typetrigger',
    'camp_channelemail', 'camp_channelmobile_push', 'camp_channelmultichannel', 'camp_channelsms',
    'camp_topicevent', 'camp_topichappy.birthday', 'camp_topicleave.review',
    'camp_topicoffer.after.purchase', 'camp_topicother', 'camp_topicsale.out',
    'channel_email', 'channel_mobile_push', 'channel_web_push',
    'email_provider_gmail.com', 'email_provider_mail.ru', 'email_provider_other',
    'is_holiday',
    'message_type_bulk', 'message_type_transactional', 'message_type_trigger',
    'platform.', 'platform.desktop', 'platform.phablet', 'platform.smartphone', 'platform.tablet',
    'prev_is_clicked', 'prev_is_complained', 'prev_is_opened', 'prev_is_unsubscribed',
    'total_campaigns', 'total_messages', 'total_purchases'
]

# =======================================================
# 2. Add-on Features (v1) - 총 3개
# : 구매 주기 및 행동 위험도 (Hazard/Refraction)
# =======================================================
cols_v1 = [
    'days_since_last_purchase',
    'feat_rtb_hazard',
    'feat_postbuy_refrac'
]

# =======================================================
# 3. Add-on Features (v2) - 총 6개
# : 캘린더 효과(주말/월초) 및 시간대 이동(Shift)
# =======================================================
cols_v2 = [
    'cal_is_weekend',
    'cal_week_of_month',
    'feat_dow_shift',
    'feat_eoq_bump',
    'feat_hour_shift',
    'feat_payday_bump'
]

# =======================================================
# 4. Add-on Features (v3) - 총 9개
# : 유저 피로도(Fatigue) 및 최근 30일 반응률(Context)
# =======================================================
cols_v3 = [
    'ctx_tc_open_rate_30d',
    'feat_fatigue',
    'feat_last_any_hours',
    'feat_last_email_hours',
    'feat_last_mobile_push_hours',
    'u_cadence_std_30d',
    'u_click_rate_30d',
    'u_open_cnt_30d',
    'u_open_rate_30d'
]

# =======================================================
# 5. Add-on Features (v4) - 총 5개
# : 토픽 신선도 및 행동 경로 유사성 (Sequence/Path)
# =======================================================
cols_v4 = [
    'feat_like_last_success',
    'feat_path_align',
    'feat_topic_novelty',
    'topic_N7',
    'topic_t_since_hours'
]

def get_feat_cols(df):
    """
    데이터프레임에서 학습에 사용할 최종 수치형 변수 리스트를 반환합니다.
    Target과 제외 리스트(ID, Leakage, Collinear)를 필터링합니다.
    """
    # 1. 모든 수치형 컬럼 추출
    num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    
    # 2. 제외 대상 필터링 (Target + Drop List)
    final_cols = list(cols_v0 + cols_v3)# + cols_v2 + cols_v3 + cols_v4)
    
    # 3. 정렬 (모델 재현성을 위해 이름순 정렬)
    return sorted(final_cols)

# -------------------------------------------------------
# 실행 및 결과 확인
# -------------------------------------------------------
# train_df는 이미 로드되어 있다고 가정
feat_cols = get_feat_cols(train_df)
n_feat = len(feat_cols)

# LSTM용 3차원 변환(reshape)을 제거하고 2차원 그대로 사용합니다.
def prepare_data_mlp(df, feature_columns):
    X = df[feature_columns].fillna(0).astype(np.float32).to_numpy()
    Y = df[TARGET].fillna(0).astype(np.int32).to_numpy()
    # LSTM의 reshape((N, F, 1)) 과정을 삭제
    return X, Y

# 이후 기존 코드 실행
Xtr, Ytr = prepare_data_mlp(train_df, feat_cols)
Xva, Yva = prepare_data_mlp(val_df, feat_cols)
Xte, Yte = prepare_data_mlp(test_df, feat_cols)

print("=== Data Shapes (MLP) ===")
print(f"Train: X={Xtr.shape}, Y={Ytr.shape}")
print(f"Val  : X={Xva.shape}, Y={Yva.shape}")
print(f"Test : X={Xte.shape}, Y={Yte.shape}")


# =========================
# [변경 3] RETRAIN WITH BEST PARAMS
# =========================
print("\n[Final] Retraining MLP with best hyperparameters...")
best_params_mlp = {
      "lr": 0.0008237189558335285,
      "batch_size": 64,
      "optimizer": "rmsprop",
      "n_layers": 3,
      "dropout_rate": 0.49554443556259786,
      "l2": 0.0017558886158773755,
      "activation": "gelu",
      "units_l0": 128,
      "units_l1": 256,
      "units_l2": 96
    }

tf.keras.backend.clear_session()

activation = best_params_mlp["activation"]
opt_name   = best_params_mlp["optimizer"]
lr         = best_params_mlp["lr"]

def build_final_optimizer():
    if opt_name == "adam":
        return optimizers.Adam(lr)
    elif opt_name == "rmsprop":
        return optimizers.RMSprop(lr)
    else:
        return optimizers.SGD(
            lr,
            momentum=best_params_mlp.get("momentum", 0.0)
        )

model = models.Sequential()
model.add(layers.Input(shape=(n_feat,)))

for i in range(best_params_mlp["n_layers"]):
    model.add(
        layers.Dense(
            best_params_mlp.get(f"units_l{i}", 64),
            activation=activation,
            kernel_regularizer=regularizers.l2(best_params_mlp["l2"])
        )
    )
    model.add(layers.Dropout(best_params_mlp["dropout_rate"]))

model.add(layers.Dense(1, activation="sigmoid"))

model.compile(
    optimizer=build_final_optimizer(),
    loss="binary_crossentropy"
)

es = callbacks.EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)
rlr = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2, min_lr=1e-6)

history = model.fit(
    Xtr, Ytr,
    validation_data=(Xva, Yva),
    epochs=EPOCHS,
    batch_size=best_params_mlp["batch_size"],
    verbose=2,
    callbacks=[es, rlr]
)


# =========================
# FINAL EVALUATION (수동 metric)
# =========================
y_prob = model.predict(Xte, verbose=0).ravel()
y_true = Yte
n_features_used = Xte.shape[1]
final_metrics, (tn, fp, fn, tp) = compute_classification_metrics(
    y_true, y_prob, thr=OPERATING_THR, n_features=n_features_used
)

final_metrics.update({
    "mode": MODE,
    "split": SPLIT_STRATEGY,
    "best_params": best_params_mlp
})

print(json.dumps({"metrics": final_metrics}, indent=2))
print("confusion_matrix [tn fp fn tp]:", tn, fp, fn, tp)
# Out:
# 2025-12-20 18:27:31.445377: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-20 18:27:31.577872: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766222851.627916 1005382 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766222851.643537 1005382 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766222851.761465 1005382 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766222851.761475 1005382 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766222851.761476 1005382 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766222851.761477 1005382 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-20 18:27:31.777550: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [LOAD] Base: ./featured_all.parquet
#
# [FINAL DATA] Total Shape: (433520, 124)
# ========================================
# [dataset(raw)] n=433,520  pos=43,352  rate=0.100000
# [dataset(after 100K sampling)] n=100,000  pos=10,000  rate=0.100000
# [check dataset(100K)] pos_rate=0.100000  target=0.10  diff=+0.000000  OK
# === Data Shapes (MLP) ===
# Train: X=(70000, 50), Y=(70000,)
# Val  : X=(15000, 50), Y=(15000,)
# Test : X=(15000, 50), Y=(15000,)
#
# [Final] Retraining MLP with best hyperparameters...
# I0000 00:00:1766222856.406147 1005382 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21770 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# I0000 00:00:1766222856.406985 1005382 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 21770 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:03:00.0, compute capability: 8.6
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1766222858.409062 1005967 service.cc:152] XLA service 0x74ac9c0084f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1766222858.409087 1005967 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# I0000 00:00:1766222858.409089 1005967 service.cc:160]   StreamExecutor device (1): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2025-12-20 18:27:38.488151: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1766222858.617251 1005967 cuda_dnn.cc:529] Loaded cuDNN version 90501
# I0000 00:00:1766222859.898412 1005967 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1094/1094 - 6s - 5ms/step - loss: 4.2220 - val_loss: 0.5946 - learning_rate: 8.2372e-04
# Epoch 2/50
# 1094/1094 - 2s - 2ms/step - loss: 0.5408 - val_loss: 0.2251 - learning_rate: 8.2372e-04
# Epoch 3/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1909 - val_loss: 0.1670 - learning_rate: 8.2372e-04
# Epoch 4/50
# 1094/1094 - 2s - 1ms/step - loss: 0.1758 - val_loss: 0.1682 - learning_rate: 8.2372e-04
# Epoch 5/50
# 1094/1094 - 2s - 1ms/step - loss: 0.1739 - val_loss: 0.1743 - learning_rate: 8.2372e-04
# Epoch 6/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1665 - val_loss: 0.1578 - learning_rate: 4.1186e-04
# Epoch 7/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1644 - val_loss: 0.1528 - learning_rate: 4.1186e-04
# Epoch 8/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1621 - val_loss: 0.1498 - learning_rate: 4.1186e-04
# Epoch 9/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1589 - val_loss: 0.1461 - learning_rate: 4.1186e-04
# Epoch 10/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1568 - val_loss: 0.1506 - learning_rate: 4.1186e-04
# Epoch 11/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1567 - val_loss: 0.1429 - learning_rate: 4.1186e-04
# Epoch 12/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1548 - val_loss: 0.1518 - learning_rate: 4.1186e-04
# Epoch 13/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1551 - val_loss: 0.1426 - learning_rate: 4.1186e-04
# Epoch 14/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1540 - val_loss: 0.1445 - learning_rate: 4.1186e-04
# Epoch 15/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1535 - val_loss: 0.1572 - learning_rate: 4.1186e-04
# Epoch 16/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1471 - val_loss: 0.1319 - learning_rate: 2.0593e-04
# Epoch 17/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1456 - val_loss: 0.1336 - learning_rate: 2.0593e-04
# Epoch 18/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1441 - val_loss: 0.1315 - learning_rate: 2.0593e-04
# Epoch 19/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1436 - val_loss: 0.1344 - learning_rate: 2.0593e-04
# Epoch 20/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1419 - val_loss: 0.1277 - learning_rate: 2.0593e-04
# Epoch 21/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1423 - val_loss: 0.1279 - learning_rate: 2.0593e-04
# Epoch 22/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1412 - val_loss: 0.1275 - learning_rate: 2.0593e-04
# Epoch 23/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1402 - val_loss: 0.1260 - learning_rate: 2.0593e-04
# Epoch 24/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1412 - val_loss: 0.1245 - learning_rate: 2.0593e-04
# Epoch 25/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1404 - val_loss: 0.1345 - learning_rate: 2.0593e-04
# Epoch 26/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1405 - val_loss: 0.1361 - learning_rate: 2.0593e-04
# Epoch 27/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1352 - val_loss: 0.1215 - learning_rate: 1.0296e-04
# Epoch 28/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1341 - val_loss: 0.1247 - learning_rate: 1.0296e-04
# Epoch 29/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1331 - val_loss: 0.1205 - learning_rate: 1.0296e-04
# Epoch 30/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1335 - val_loss: 0.1228 - learning_rate: 1.0296e-04
# Epoch 31/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1329 - val_loss: 0.1275 - learning_rate: 1.0296e-04
# Epoch 32/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1302 - val_loss: 0.1199 - learning_rate: 5.1482e-05
# Epoch 33/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1300 - val_loss: 0.1209 - learning_rate: 5.1482e-05
# Epoch 34/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1289 - val_loss: 0.1230 - learning_rate: 5.1482e-05
# Epoch 35/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1273 - val_loss: 0.1170 - learning_rate: 2.5741e-05
# Epoch 36/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1282 - val_loss: 0.1186 - learning_rate: 2.5741e-05
# Epoch 37/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1272 - val_loss: 0.1209 - learning_rate: 2.5741e-05
# Epoch 38/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1277 - val_loss: 0.1175 - learning_rate: 1.2871e-05
# Epoch 39/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1273 - val_loss: 0.1195 - learning_rate: 1.2871e-05
# Epoch 40/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1253 - val_loss: 0.1186 - learning_rate: 6.4353e-06
# {
#   "metrics": {
#     "accuracy": 0.9669333333332688,
#     "precision": 0.9666064981940735,
#     "recall": 0.6999999999995425,
#     "specificity": 0.9972531551595399,
#     "f1": 0.8119787713089953,
#     "roc_auc": 0.9742832049920499,
#     "n_eval": 15000,
#     "pos_rate_eval": 0.102,
#     "aic": 2995.692368511397,
#     "bic": 3376.4826425156143,
#     "log_likelihood": -1447.8461842556985,
#     "n_features": 50,
#     "mode": "STRICT_CAUSAL",
#     "split": "RANDOM_ROW",
#     "best_params": {
#       "lr": 0.0008237189558335285,
#       "batch_size": 64,
#       "optimizer": "rmsprop",
#       "n_layers": 3,
#       "dropout_rate": 0.49554443556259786,
#       "l2": 0.0017558886158773755,
#       "activation": "gelu",
#       "units_l0": 128,
#       "units_l1": 256,
#       "units_l2": 96
#     }
#   }
# }
# confusion_matrix [tn fp fn tp]: 13433 37 459 1071

# %%
import os, random, json, warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

# Tensorflow 관련 제거하고 Scikit-Learn RandomForest 추가
from sklearn.ensemble import RandomForestClassifier
import tensorflow as tf
from tensorflow.keras import layers, regularizers, models, optimizers, callbacks

# Optuna
import optuna
from optuna.integration import TFKerasPruningCallback
from sklearn.model_selection import StratifiedKFold
import gc
import xgboost as xgb
# =========================
# CONFIG
# =========================
SEED = 1
MODE = "STRICT_CAUSAL"
SPLIT_STRATEGY = "RANDOM_ROW"
POS_RATIO = 0.10
TARGET_TOTAL = 100_000

EPOCHS = 50           # 최종 재학습 epoch
VAL_FRAC = 0.15
TEST_FRAC = 0.15
TIME_HOLDOUT_TEST_WEEKS = 8
TOL = 0.0025

# ✅ Optuna(튜닝) 전용 설정
N_TRIALS = 10             # Optuna trial 수
EPOCHS_TUNE = 15         # 튜닝용 epoch (CV 안에서)
MAX_TUNE_SAMPLES = 30_000  # fold별 train에서 최대 이만큼만 사용

# 최종 평가용 threshold
OPERATING_THR = 0.5
DATA_DIR = "."
# 고정 시드
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED); np.random.seed(SEED);
rng = np.random.RandomState(SEED)

# 1. Base 데이터 (v0) 로드
path_v0 = os.path.join(DATA_DIR, "featured_all.parquet")
print(f"[LOAD] Base: {path_v0}")
final_data = pd.read_parquet(path_v0)

print(f"\n[FINAL DATA] Total Shape: {final_data.shape}")
print("========================================")

# =========================
# 수동 metric + AUC 계산 함수
# =========================
def compute_roc_auc_manual(y_true, y_prob):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob, dtype=float)

    # NaN 제거
    mask = ~np.isnan(y_prob)
    y_true = y_true[mask]
    y_prob = y_prob[mask]

    n_pos = (y_true == 1).sum()
    n_neg = (y_true == 0).sum()
    if n_pos == 0 or n_neg == 0:
        return float("nan")

    # 확률 내림차순 정렬
    order = np.argsort(-y_prob)
    y_true_sorted = y_true[order]

    cum_pos = np.cumsum(y_true_sorted == 1)
    cum_neg = np.cumsum(y_true_sorted == 0)

    tpr = cum_pos / n_pos
    fpr = cum_neg / n_neg

    # 사다리꼴 적분
    auc = 0.0
    prev_fpr = 0.0
    prev_tpr = 0.0
    for i in range(len(y_true_sorted)):
        auc += (fpr[i] - prev_fpr) * (tpr[i] + prev_tpr) / 2.0
        prev_fpr = fpr[i]
        prev_tpr = tpr[i]

    return float(auc)


# =========================
# 수동 metric + AUC + AIC/BIC 계산 함수
# =========================
def compute_aic_bic_manual(y_true, y_prob, n_features):
    """
    Log-Likelihood를 기반으로 AIC, BIC 계산
    """
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob, dtype=float)
    
    # Log(0) 방지를 위한 clipping (epsilon)
    eps = 1e-15
    y_prob = np.clip(y_prob, eps, 1 - eps)
    
    # Log Likelihood 계산
    # L = sum( y*log(p) + (1-y)*log(1-p) )
    log_likelihood = np.sum(y_true * np.log(y_prob) + (1 - y_true) * np.log(1 - y_prob))
    
    n = len(y_true)
    k = n_features
    
    aic = 2 * k - 2 * log_likelihood
    bic = k * np.log(n) - 2 * log_likelihood
    
    return float(aic), float(bic), float(log_likelihood)

def compute_classification_metrics(y_true, y_prob, thr=0.8, n_features=None):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob, dtype=float)
    y_pred = (y_prob >= thr).astype(int)

    tp = int(((y_true == 1) & (y_pred == 1)).sum())
    tn = int(((y_true == 0) & (y_pred == 0)).sum())
    fp = int(((y_true == 0) & (y_pred == 1)).sum())
    fn = int(((y_true == 1) & (y_pred == 0)).sum())

    n = len(y_true)
    eps = 1e-9

    accuracy    = (tp + tn) / (n + eps)
    precision   = tp / (tp + fp + eps)
    recall      = tp / (tp + fn + eps)
    specificity = tn / (tn + fp + eps)
    f1          = 2 * precision * recall / (precision + recall + eps)

    roc_auc = compute_roc_auc_manual(y_true, y_prob)

    metrics = {
        "accuracy":       float(accuracy),
        "precision":      float(precision),
        "recall":         float(recall),
        "specificity":    float(specificity),
        "f1":             float(f1),
        "roc_auc":        float(roc_auc),
        "n_eval":         int(n),
        "pos_rate_eval":  float(y_true.mean()),
    }

    # [추가됨] n_features가 들어오면 AIC/BIC 계산
    if n_features is not None:
        aic, bic, ll = compute_aic_bic_manual(y_true, y_prob, n_features)
        metrics["aic"] = aic
        metrics["bic"] = bic
        metrics["log_likelihood"] = ll
        metrics["n_features"] = int(n_features)

    cm = (tn, fp, fn, tp)
    return metrics, cm


# =========================
# SPLIT
# =========================
def brief(name, df):
    if df is None or len(df) == 0:
        print(f"[{name}] n=0"); return
    pos = int(df["is_purchased"].sum())
    n = len(df); rate = pos / max(n, 1)
    print(f"[{name}] n={n:,}  pos={pos:,}  rate={rate:.6f}")
def brief(name, df):
    if df is None or len(df) == 0:
        print(f"[{name}] n=0"); return
    pos = int(df["is_purchased"].sum())
    n = len(df); rate = pos / max(n, 1)
    print(f"[{name}] n={n:,}  pos={pos:,}  rate={rate:.6f}")

def check_ratio(df, target_ratio=0.10, tol=TOL, name="dataset"):
    if len(df) == 0: return
    r = float(df["is_purchased"].mean())
    ok = abs(r - target_ratio) <= tol
    print(f"[check {name}] pos_rate={r:.6f}  target={target_ratio:.2f}  diff={r-target_ratio:+.6f}  {'OK' if ok else 'WARN'}")

def stratified_fixed_sample(df, target_col="is_purchased", total_n=100_000, pos_ratio=0.10, seed=SEED):
    n_pos_k = int(round(total_n * pos_ratio))
    n_neg_k = total_n - n_pos_k
    pos = df[df[target_col] == 1]
    neg = df[df[target_col] == 0]
    pos_s = pos.sample(n=min(n_pos_k, len(pos)), random_state=seed, replace=False)
    neg_s = neg.sample(n=min(n_neg_k, len(neg)), random_state=seed, replace=False)
    out = pd.concat([pos_s, neg_s], axis=0).sample(frac=1.0, random_state=seed).reset_index(drop=True)
    return out

def split_random_row_simple(df, val_frac=VAL_FRAC, test_frac=TEST_FRAC, seed=SEED):
    rng_local = np.random.RandomState(seed)
    N = len(df)
    idx = np.arange(N); rng_local.shuffle(idx)
    n_test = int(round(N * test_frac))
    n_val  = int(round(N * val_frac))
    te_idx = idx[:n_test]
    va_idx = idx[n_test:n_test+n_val]
    tr_idx = idx[n_test+n_val:]
    te = df.iloc[te_idx].reset_index(drop=True)
    va = df.iloc[va_idx].reset_index(drop=True)
    tr = df.iloc[tr_idx].reset_index(drop=True)
    return tr, va, te

dataset = final_data.sample(frac=1.0, random_state=SEED).reset_index(drop=True)
brief("dataset(raw)", dataset)
if TARGET_TOTAL and len(dataset) > TARGET_TOTAL:
    dataset = stratified_fixed_sample(dataset, target_col="is_purchased",
                                      total_n=TARGET_TOTAL, pos_ratio=POS_RATIO, seed=SEED)
brief("dataset(after 100K sampling)", dataset)
check_ratio(dataset, POS_RATIO, name="dataset(100K)")

if SPLIT_STRATEGY == "RANDOM_ROW":
    train_df, val_df, test_df = split_random_row_simple(dataset)
elif SPLIT_STRATEGY == "TIME_HOLDOUT":
    train_df, val_df, test_df = split_time_holdout(dataset)
else:
    train_df, val_df, test_df = split_user_disjoint(dataset)
    
TARGET = "is_purchased"

# =======================================================
# 1. Base Features (v0) - 총 41개
# : 캠페인, 채널, 플랫폼, 기본 이력 통계 등 가장 기초적인 정보
# =======================================================
cols_v0 = [
    'avg_campaign_duration', 'avg_time_since_complaint', 'avg_time_since_first_purchase',
    'avg_time_since_last_click', 'avg_time_since_last_open', 'avg_time_since_unsubscribe',
    'camp_campaign_typebulk', 'camp_campaign_typetransactional', 'camp_campaign_typetrigger',
    'camp_channelemail', 'camp_channelmobile_push', 'camp_channelmultichannel', 'camp_channelsms',
    'camp_topicevent', 'camp_topichappy.birthday', 'camp_topicleave.review',
    'camp_topicoffer.after.purchase', 'camp_topicother', 'camp_topicsale.out',
    'channel_email', 'channel_mobile_push', 'channel_web_push',
    'email_provider_gmail.com', 'email_provider_mail.ru', 'email_provider_other',
    'is_holiday',
    'message_type_bulk', 'message_type_transactional', 'message_type_trigger',
    'platform.', 'platform.desktop', 'platform.phablet', 'platform.smartphone', 'platform.tablet',
    'prev_is_clicked', 'prev_is_complained', 'prev_is_opened', 'prev_is_unsubscribed',
    'total_campaigns', 'total_messages', 'total_purchases'
]

# =======================================================
# 2. Add-on Features (v1) - 총 3개
# : 구매 주기 및 행동 위험도 (Hazard/Refraction)
# =======================================================
cols_v1 = [
    'days_since_last_purchase',
    'feat_rtb_hazard',
    'feat_postbuy_refrac'
]

# =======================================================
# 3. Add-on Features (v2) - 총 6개
# : 캘린더 효과(주말/월초) 및 시간대 이동(Shift)
# =======================================================
cols_v2 = [
    'cal_is_weekend',
    'cal_week_of_month',
    'feat_dow_shift',
    'feat_eoq_bump',
    'feat_hour_shift',
    'feat_payday_bump'
]

# =======================================================
# 4. Add-on Features (v3) - 총 9개
# : 유저 피로도(Fatigue) 및 최근 30일 반응률(Context)
# =======================================================
cols_v3 = [
    'ctx_tc_open_rate_30d',
    'feat_fatigue',
    'feat_last_any_hours',
    'feat_last_email_hours',
    'feat_last_mobile_push_hours',
    'u_cadence_std_30d',
    'u_click_rate_30d',
    'u_open_cnt_30d',
    'u_open_rate_30d'
]

# =======================================================
# 5. Add-on Features (v4) - 총 5개
# : 토픽 신선도 및 행동 경로 유사성 (Sequence/Path)
# =======================================================
cols_v4 = [
    'feat_like_last_success',
    'feat_path_align',
    'feat_topic_novelty',
    'topic_N7',
    'topic_t_since_hours'
]

def get_feat_cols(df):
    """
    데이터프레임에서 학습에 사용할 최종 수치형 변수 리스트를 반환합니다.
    Target과 제외 리스트(ID, Leakage, Collinear)를 필터링합니다.
    """
    # 1. 모든 수치형 컬럼 추출
    num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    
    # 2. 제외 대상 필터링 (Target + Drop List)
    final_cols = list(cols_v0 + cols_v4)# + cols_v2 + cols_v3 + cols_v4)
    
    # 3. 정렬 (모델 재현성을 위해 이름순 정렬)
    return sorted(final_cols)

# -------------------------------------------------------
# 실행 및 결과 확인
# -------------------------------------------------------
# train_df는 이미 로드되어 있다고 가정
feat_cols = get_feat_cols(train_df)
n_feat = len(feat_cols)

# LSTM용 3차원 변환(reshape)을 제거하고 2차원 그대로 사용합니다.
def prepare_data_mlp(df, feature_columns):
    X = df[feature_columns].fillna(0).astype(np.float32).to_numpy()
    Y = df[TARGET].fillna(0).astype(np.int32).to_numpy()
    # LSTM의 reshape((N, F, 1)) 과정을 삭제
    return X, Y

# 이후 기존 코드 실행
Xtr, Ytr = prepare_data_mlp(train_df, feat_cols)
Xva, Yva = prepare_data_mlp(val_df, feat_cols)
Xte, Yte = prepare_data_mlp(test_df, feat_cols)

print("=== Data Shapes (MLP) ===")
print(f"Train: X={Xtr.shape}, Y={Ytr.shape}")
print(f"Val  : X={Xva.shape}, Y={Yva.shape}")
print(f"Test : X={Xte.shape}, Y={Yte.shape}")


# =========================
# [변경 3] RETRAIN WITH BEST PARAMS
# =========================
print("\n[Final] Retraining MLP with best hyperparameters...")
best_params_mlp = {
      "lr": 0.0008237189558335285,
      "batch_size": 64,
      "optimizer": "rmsprop",
      "n_layers": 3,
      "dropout_rate": 0.49554443556259786,
      "l2": 0.0017558886158773755,
      "activation": "gelu",
      "units_l0": 128,
      "units_l1": 256,
      "units_l2": 96
    }

tf.keras.backend.clear_session()

activation = best_params_mlp["activation"]
opt_name   = best_params_mlp["optimizer"]
lr         = best_params_mlp["lr"]

def build_final_optimizer():
    if opt_name == "adam":
        return optimizers.Adam(lr)
    elif opt_name == "rmsprop":
        return optimizers.RMSprop(lr)
    else:
        return optimizers.SGD(
            lr,
            momentum=best_params_mlp.get("momentum", 0.0)
        )

model = models.Sequential()
model.add(layers.Input(shape=(n_feat,)))

for i in range(best_params_mlp["n_layers"]):
    model.add(
        layers.Dense(
            best_params_mlp.get(f"units_l{i}", 64),
            activation=activation,
            kernel_regularizer=regularizers.l2(best_params_mlp["l2"])
        )
    )
    model.add(layers.Dropout(best_params_mlp["dropout_rate"]))

model.add(layers.Dense(1, activation="sigmoid"))

model.compile(
    optimizer=build_final_optimizer(),
    loss="binary_crossentropy"
)

es = callbacks.EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)
rlr = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2, min_lr=1e-6)

history = model.fit(
    Xtr, Ytr,
    validation_data=(Xva, Yva),
    epochs=EPOCHS,
    batch_size=best_params_mlp["batch_size"],
    verbose=2,
    callbacks=[es, rlr]
)


# =========================
# FINAL EVALUATION (수동 metric)
# =========================
y_prob = model.predict(Xte, verbose=0).ravel()
y_true = Yte
n_features_used = Xte.shape[1]
final_metrics, (tn, fp, fn, tp) = compute_classification_metrics(
    y_true, y_prob, thr=OPERATING_THR, n_features=n_features_used
)

final_metrics.update({
    "mode": MODE,
    "split": SPLIT_STRATEGY,
    "best_params": best_params_mlp
})

print(json.dumps({"metrics": final_metrics}, indent=2))
print("confusion_matrix [tn fp fn tp]:", tn, fp, fn, tp)
# Out:
# [LOAD] Base: ./featured_all.parquet
#
# [FINAL DATA] Total Shape: (433520, 124)
# ========================================
# [dataset(raw)] n=433,520  pos=43,352  rate=0.100000
# [dataset(after 100K sampling)] n=100,000  pos=10,000  rate=0.100000
# [check dataset(100K)] pos_rate=0.100000  target=0.10  diff=+0.000000  OK
# === Data Shapes (MLP) ===
# Train: X=(70000, 46), Y=(70000,)
# Val  : X=(15000, 46), Y=(15000,)
# Test : X=(15000, 46), Y=(15000,)
#
# [Final] Retraining MLP with best hyperparameters...
# Epoch 1/50
# 1094/1094 - 6s - 6ms/step - loss: 2.8197 - val_loss: 0.4313 - learning_rate: 8.2372e-04
# Epoch 2/50
# 1094/1094 - 2s - 2ms/step - loss: 0.6530 - val_loss: 0.5448 - learning_rate: 8.2372e-04
# Epoch 3/50
# 1094/1094 - 2s - 2ms/step - loss: 0.3610 - val_loss: 0.2644 - learning_rate: 8.2372e-04
# Epoch 4/50
# 1094/1094 - 2s - 2ms/step - loss: 0.2368 - val_loss: 0.2577 - learning_rate: 8.2372e-04
# Epoch 5/50
# 1094/1094 - 2s - 2ms/step - loss: 0.2176 - val_loss: 0.1734 - learning_rate: 8.2372e-04
# Epoch 6/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1874 - val_loss: 0.1754 - learning_rate: 8.2372e-04
# Epoch 7/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1848 - val_loss: 0.1751 - learning_rate: 8.2372e-04
# Epoch 8/50
# 1094/1094 - 2s - 1ms/step - loss: 0.1775 - val_loss: 0.1690 - learning_rate: 4.1186e-04
# Epoch 9/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1745 - val_loss: 0.1688 - learning_rate: 4.1186e-04
# Epoch 10/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1749 - val_loss: 0.1700 - learning_rate: 4.1186e-04
# Epoch 11/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1743 - val_loss: 0.1670 - learning_rate: 4.1186e-04
# Epoch 12/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1741 - val_loss: 0.1658 - learning_rate: 4.1186e-04
# Epoch 13/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1747 - val_loss: 0.1663 - learning_rate: 4.1186e-04
# Epoch 14/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1754 - val_loss: 0.1643 - learning_rate: 4.1186e-04
# Epoch 15/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1747 - val_loss: 0.1662 - learning_rate: 4.1186e-04
# Epoch 16/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1741 - val_loss: 0.1650 - learning_rate: 4.1186e-04
# Epoch 17/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1701 - val_loss: 0.1602 - learning_rate: 2.0593e-04
# Epoch 18/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1695 - val_loss: 0.1615 - learning_rate: 2.0593e-04
# Epoch 19/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1698 - val_loss: 0.1632 - learning_rate: 2.0593e-04
# Epoch 20/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1655 - val_loss: 0.1591 - learning_rate: 1.0296e-04
# Epoch 21/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1661 - val_loss: 0.1612 - learning_rate: 1.0296e-04
# Epoch 22/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1655 - val_loss: 0.1601 - learning_rate: 1.0296e-04
# Epoch 23/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1647 - val_loss: 0.1592 - learning_rate: 5.1482e-05
# Epoch 24/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1639 - val_loss: 0.1624 - learning_rate: 5.1482e-05
# Epoch 25/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1640 - val_loss: 0.1617 - learning_rate: 2.5741e-05
# {
#   "metrics": {
#     "accuracy": 0.9429999999999371,
#     "precision": 0.8813559322023939,
#     "recall": 0.5098039215682942,
#     "specificity": 0.9922048997772092,
#     "f1": 0.6459627324543857,
#     "roc_auc": 0.9562027939114472,
#     "n_eval": 15000,
#     "pos_rate_eval": 0.102,
#     "aic": 4222.481113696739,
#     "bic": 4572.808165780619,
#     "log_likelihood": -2065.2405568483696,
#     "n_features": 46,
#     "mode": "STRICT_CAUSAL",
#     "split": "RANDOM_ROW",
#     "best_params": {
#       "lr": 0.0008237189558335285,
#       "batch_size": 64,
#       "optimizer": "rmsprop",
#       "n_layers": 3,
#       "dropout_rate": 0.49554443556259786,
#       "l2": 0.0017558886158773755,
#       "activation": "gelu",
#       "units_l0": 128,
#       "units_l1": 256,
#       "units_l2": 96
#     }
#   }
# }
# confusion_matrix [tn fp fn tp]: 13365 105 750 780

# %%
import os, random, json, warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

# Tensorflow 관련 제거하고 Scikit-Learn RandomForest 추가
from sklearn.ensemble import RandomForestClassifier
import tensorflow as tf
from tensorflow.keras import layers, regularizers, models, optimizers, callbacks

# Optuna
import optuna
from optuna.integration import TFKerasPruningCallback
from sklearn.model_selection import StratifiedKFold
import gc
import xgboost as xgb
# =========================
# CONFIG
# =========================
SEED = 1
MODE = "STRICT_CAUSAL"
SPLIT_STRATEGY = "RANDOM_ROW"
POS_RATIO = 0.10
TARGET_TOTAL = 100_000

EPOCHS = 50           # 최종 재학습 epoch
VAL_FRAC = 0.15
TEST_FRAC = 0.15
TIME_HOLDOUT_TEST_WEEKS = 8
TOL = 0.0025

# ✅ Optuna(튜닝) 전용 설정
N_TRIALS = 10             # Optuna trial 수
EPOCHS_TUNE = 15         # 튜닝용 epoch (CV 안에서)
MAX_TUNE_SAMPLES = 30_000  # fold별 train에서 최대 이만큼만 사용

# 최종 평가용 threshold
OPERATING_THR = 0.5
DATA_DIR = "."
# 고정 시드
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED); np.random.seed(SEED);
rng = np.random.RandomState(SEED)

# 1. Base 데이터 (v0) 로드
path_v0 = os.path.join(DATA_DIR, "featured_all.parquet")
print(f"[LOAD] Base: {path_v0}")
final_data = pd.read_parquet(path_v0)

print(f"\n[FINAL DATA] Total Shape: {final_data.shape}")
print("========================================")

# =========================
# 수동 metric + AUC 계산 함수
# =========================
def compute_roc_auc_manual(y_true, y_prob):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob, dtype=float)

    # NaN 제거
    mask = ~np.isnan(y_prob)
    y_true = y_true[mask]
    y_prob = y_prob[mask]

    n_pos = (y_true == 1).sum()
    n_neg = (y_true == 0).sum()
    if n_pos == 0 or n_neg == 0:
        return float("nan")

    # 확률 내림차순 정렬
    order = np.argsort(-y_prob)
    y_true_sorted = y_true[order]

    cum_pos = np.cumsum(y_true_sorted == 1)
    cum_neg = np.cumsum(y_true_sorted == 0)

    tpr = cum_pos / n_pos
    fpr = cum_neg / n_neg

    # 사다리꼴 적분
    auc = 0.0
    prev_fpr = 0.0
    prev_tpr = 0.0
    for i in range(len(y_true_sorted)):
        auc += (fpr[i] - prev_fpr) * (tpr[i] + prev_tpr) / 2.0
        prev_fpr = fpr[i]
        prev_tpr = tpr[i]

    return float(auc)


# =========================
# 수동 metric + AUC + AIC/BIC 계산 함수
# =========================
def compute_aic_bic_manual(y_true, y_prob, n_features):
    """
    Log-Likelihood를 기반으로 AIC, BIC 계산
    """
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob, dtype=float)
    
    # Log(0) 방지를 위한 clipping (epsilon)
    eps = 1e-15
    y_prob = np.clip(y_prob, eps, 1 - eps)
    
    # Log Likelihood 계산
    # L = sum( y*log(p) + (1-y)*log(1-p) )
    log_likelihood = np.sum(y_true * np.log(y_prob) + (1 - y_true) * np.log(1 - y_prob))
    
    n = len(y_true)
    k = n_features
    
    aic = 2 * k - 2 * log_likelihood
    bic = k * np.log(n) - 2 * log_likelihood
    
    return float(aic), float(bic), float(log_likelihood)

def compute_classification_metrics(y_true, y_prob, thr=0.8, n_features=None):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob, dtype=float)
    y_pred = (y_prob >= thr).astype(int)

    tp = int(((y_true == 1) & (y_pred == 1)).sum())
    tn = int(((y_true == 0) & (y_pred == 0)).sum())
    fp = int(((y_true == 0) & (y_pred == 1)).sum())
    fn = int(((y_true == 1) & (y_pred == 0)).sum())

    n = len(y_true)
    eps = 1e-9

    accuracy    = (tp + tn) / (n + eps)
    precision   = tp / (tp + fp + eps)
    recall      = tp / (tp + fn + eps)
    specificity = tn / (tn + fp + eps)
    f1          = 2 * precision * recall / (precision + recall + eps)

    roc_auc = compute_roc_auc_manual(y_true, y_prob)

    metrics = {
        "accuracy":       float(accuracy),
        "precision":      float(precision),
        "recall":         float(recall),
        "specificity":    float(specificity),
        "f1":             float(f1),
        "roc_auc":        float(roc_auc),
        "n_eval":         int(n),
        "pos_rate_eval":  float(y_true.mean()),
    }

    # [추가됨] n_features가 들어오면 AIC/BIC 계산
    if n_features is not None:
        aic, bic, ll = compute_aic_bic_manual(y_true, y_prob, n_features)
        metrics["aic"] = aic
        metrics["bic"] = bic
        metrics["log_likelihood"] = ll
        metrics["n_features"] = int(n_features)

    cm = (tn, fp, fn, tp)
    return metrics, cm


# =========================
# SPLIT
# =========================
def brief(name, df):
    if df is None or len(df) == 0:
        print(f"[{name}] n=0"); return
    pos = int(df["is_purchased"].sum())
    n = len(df); rate = pos / max(n, 1)
    print(f"[{name}] n={n:,}  pos={pos:,}  rate={rate:.6f}")
def brief(name, df):
    if df is None or len(df) == 0:
        print(f"[{name}] n=0"); return
    pos = int(df["is_purchased"].sum())
    n = len(df); rate = pos / max(n, 1)
    print(f"[{name}] n={n:,}  pos={pos:,}  rate={rate:.6f}")

def check_ratio(df, target_ratio=0.10, tol=TOL, name="dataset"):
    if len(df) == 0: return
    r = float(df["is_purchased"].mean())
    ok = abs(r - target_ratio) <= tol
    print(f"[check {name}] pos_rate={r:.6f}  target={target_ratio:.2f}  diff={r-target_ratio:+.6f}  {'OK' if ok else 'WARN'}")

def stratified_fixed_sample(df, target_col="is_purchased", total_n=100_000, pos_ratio=0.10, seed=SEED):
    n_pos_k = int(round(total_n * pos_ratio))
    n_neg_k = total_n - n_pos_k
    pos = df[df[target_col] == 1]
    neg = df[df[target_col] == 0]
    pos_s = pos.sample(n=min(n_pos_k, len(pos)), random_state=seed, replace=False)
    neg_s = neg.sample(n=min(n_neg_k, len(neg)), random_state=seed, replace=False)
    out = pd.concat([pos_s, neg_s], axis=0).sample(frac=1.0, random_state=seed).reset_index(drop=True)
    return out

def split_random_row_simple(df, val_frac=VAL_FRAC, test_frac=TEST_FRAC, seed=SEED):
    rng_local = np.random.RandomState(seed)
    N = len(df)
    idx = np.arange(N); rng_local.shuffle(idx)
    n_test = int(round(N * test_frac))
    n_val  = int(round(N * val_frac))
    te_idx = idx[:n_test]
    va_idx = idx[n_test:n_test+n_val]
    tr_idx = idx[n_test+n_val:]
    te = df.iloc[te_idx].reset_index(drop=True)
    va = df.iloc[va_idx].reset_index(drop=True)
    tr = df.iloc[tr_idx].reset_index(drop=True)
    return tr, va, te

dataset = final_data.sample(frac=1.0, random_state=SEED).reset_index(drop=True)
brief("dataset(raw)", dataset)
if TARGET_TOTAL and len(dataset) > TARGET_TOTAL:
    dataset = stratified_fixed_sample(dataset, target_col="is_purchased",
                                      total_n=TARGET_TOTAL, pos_ratio=POS_RATIO, seed=SEED)
brief("dataset(after 100K sampling)", dataset)
check_ratio(dataset, POS_RATIO, name="dataset(100K)")

if SPLIT_STRATEGY == "RANDOM_ROW":
    train_df, val_df, test_df = split_random_row_simple(dataset)
elif SPLIT_STRATEGY == "TIME_HOLDOUT":
    train_df, val_df, test_df = split_time_holdout(dataset)
else:
    train_df, val_df, test_df = split_user_disjoint(dataset)
    
TARGET = "is_purchased"

# =======================================================
# 1. Base Features (v0) - 총 41개
# : 캠페인, 채널, 플랫폼, 기본 이력 통계 등 가장 기초적인 정보
# =======================================================
cols_v0 = [
    'avg_campaign_duration', 'avg_time_since_complaint', 'avg_time_since_first_purchase',
    'avg_time_since_last_click', 'avg_time_since_last_open', 'avg_time_since_unsubscribe',
    'camp_campaign_typebulk', 'camp_campaign_typetransactional', 'camp_campaign_typetrigger',
    'camp_channelemail', 'camp_channelmobile_push', 'camp_channelmultichannel', 'camp_channelsms',
    'camp_topicevent', 'camp_topichappy.birthday', 'camp_topicleave.review',
    'camp_topicoffer.after.purchase', 'camp_topicother', 'camp_topicsale.out',
    'channel_email', 'channel_mobile_push', 'channel_web_push',
    'email_provider_gmail.com', 'email_provider_mail.ru', 'email_provider_other',
    'is_holiday',
    'message_type_bulk', 'message_type_transactional', 'message_type_trigger',
    'platform.', 'platform.desktop', 'platform.phablet', 'platform.smartphone', 'platform.tablet',
    'prev_is_clicked', 'prev_is_complained', 'prev_is_opened', 'prev_is_unsubscribed',
    'total_campaigns', 'total_messages', 'total_purchases'
]

# =======================================================
# 2. Add-on Features (v1) - 총 3개
# : 구매 주기 및 행동 위험도 (Hazard/Refraction)
# =======================================================
cols_v1 = [
    'days_since_last_purchase',
    'feat_rtb_hazard',
    'feat_postbuy_refrac'
]

# =======================================================
# 3. Add-on Features (v2) - 총 6개
# : 캘린더 효과(주말/월초) 및 시간대 이동(Shift)
# =======================================================
cols_v2 = [
    'cal_is_weekend',
    'cal_week_of_month',
    'feat_dow_shift',
    'feat_eoq_bump',
    'feat_hour_shift',
    'feat_payday_bump'
]

# =======================================================
# 4. Add-on Features (v3) - 총 9개
# : 유저 피로도(Fatigue) 및 최근 30일 반응률(Context)
# =======================================================
cols_v3 = [
    'ctx_tc_open_rate_30d',
    'feat_fatigue',
    'feat_last_any_hours',
    'feat_last_email_hours',
    'feat_last_mobile_push_hours',
    'u_cadence_std_30d',
    'u_click_rate_30d',
    'u_open_cnt_30d',
    'u_open_rate_30d'
]

# =======================================================
# 5. Add-on Features (v4) - 총 5개
# : 토픽 신선도 및 행동 경로 유사성 (Sequence/Path)
# =======================================================
cols_v4 = [
    'feat_like_last_success',
    'feat_path_align',
    'feat_topic_novelty',
    'topic_N7',
    'topic_t_since_hours'
]

def get_feat_cols(df):
    """
    데이터프레임에서 학습에 사용할 최종 수치형 변수 리스트를 반환합니다.
    Target과 제외 리스트(ID, Leakage, Collinear)를 필터링합니다.
    """
    # 1. 모든 수치형 컬럼 추출
    num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    
    # 2. 제외 대상 필터링 (Target + Drop List)
    final_cols = list(cols_v0 + cols_v1 + cols_v2 + cols_v3 + cols_v4)
    
    # 3. 정렬 (모델 재현성을 위해 이름순 정렬)
    return sorted(final_cols)

# -------------------------------------------------------
# 실행 및 결과 확인
# -------------------------------------------------------
# train_df는 이미 로드되어 있다고 가정
feat_cols = get_feat_cols(train_df)
n_feat = len(feat_cols)

# LSTM용 3차원 변환(reshape)을 제거하고 2차원 그대로 사용합니다.
def prepare_data_mlp(df, feature_columns):
    X = df[feature_columns].fillna(0).astype(np.float32).to_numpy()
    Y = df[TARGET].fillna(0).astype(np.int32).to_numpy()
    # LSTM의 reshape((N, F, 1)) 과정을 삭제
    return X, Y

# 이후 기존 코드 실행
Xtr, Ytr = prepare_data_mlp(train_df, feat_cols)
Xva, Yva = prepare_data_mlp(val_df, feat_cols)
Xte, Yte = prepare_data_mlp(test_df, feat_cols)

print("=== Data Shapes (MLP) ===")
print(f"Train: X={Xtr.shape}, Y={Ytr.shape}")
print(f"Val  : X={Xva.shape}, Y={Yva.shape}")
print(f"Test : X={Xte.shape}, Y={Yte.shape}")


# =========================
# [변경 3] RETRAIN WITH BEST PARAMS
# =========================
print("\n[Final] Retraining MLP with best hyperparameters...")
best_params_mlp = {
      "lr": 0.0008237189558335285,
      "batch_size": 64,
      "optimizer": "rmsprop",
      "n_layers": 3,
      "dropout_rate": 0.49554443556259786,
      "l2": 0.0017558886158773755,
      "activation": "gelu",
      "units_l0": 128,
      "units_l1": 256,
      "units_l2": 96
    }

tf.keras.backend.clear_session()

activation = best_params_mlp["activation"]
opt_name   = best_params_mlp["optimizer"]
lr         = best_params_mlp["lr"]

def build_final_optimizer():
    if opt_name == "adam":
        return optimizers.Adam(lr)
    elif opt_name == "rmsprop":
        return optimizers.RMSprop(lr)
    else:
        return optimizers.SGD(
            lr,
            momentum=best_params_mlp.get("momentum", 0.0)
        )

model = models.Sequential()
model.add(layers.Input(shape=(n_feat,)))

for i in range(best_params_mlp["n_layers"]):
    model.add(
        layers.Dense(
            best_params_mlp.get(f"units_l{i}", 64),
            activation=activation,
            kernel_regularizer=regularizers.l2(best_params_mlp["l2"])
        )
    )
    model.add(layers.Dropout(best_params_mlp["dropout_rate"]))

model.add(layers.Dense(1, activation="sigmoid"))

model.compile(
    optimizer=build_final_optimizer(),
    loss="binary_crossentropy"
)

es = callbacks.EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)
rlr = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2, min_lr=1e-6)

history = model.fit(
    Xtr, Ytr,
    validation_data=(Xva, Yva),
    epochs=EPOCHS,
    batch_size=best_params_mlp["batch_size"],
    verbose=2,
    callbacks=[es, rlr]
)


# =========================
# FINAL EVALUATION (수동 metric)
# =========================
y_prob = model.predict(Xte, verbose=0).ravel()
y_true = Yte
n_features_used = Xte.shape[1]
final_metrics, (tn, fp, fn, tp) = compute_classification_metrics(
    y_true, y_prob, thr=OPERATING_THR, n_features=n_features_used
)

final_metrics.update({
    "mode": MODE,
    "split": SPLIT_STRATEGY,
    "best_params": best_params_mlp
})

print(json.dumps({"metrics": final_metrics}, indent=2))
print("confusion_matrix [tn fp fn tp]:", tn, fp, fn, tp)
# Out:
# [LOAD] Base: ./featured_all.parquet
#
# [FINAL DATA] Total Shape: (433520, 124)
# ========================================
# [dataset(raw)] n=433,520  pos=43,352  rate=0.100000
# [dataset(after 100K sampling)] n=100,000  pos=10,000  rate=0.100000
# [check dataset(100K)] pos_rate=0.100000  target=0.10  diff=+0.000000  OK
# === Data Shapes (MLP) ===
# Train: X=(70000, 64), Y=(70000,)
# Val  : X=(15000, 64), Y=(15000,)
# Test : X=(15000, 64), Y=(15000,)
#
# [Final] Retraining MLP with best hyperparameters...
# Epoch 1/50
# 1094/1094 - 6s - 6ms/step - loss: 4.1483 - val_loss: 0.5254 - learning_rate: 8.2372e-04
# Epoch 2/50
# 1094/1094 - 2s - 2ms/step - loss: 0.5524 - val_loss: 0.2383 - learning_rate: 8.2372e-04
# Epoch 3/50
# 1094/1094 - 2s - 2ms/step - loss: 0.2036 - val_loss: 0.1684 - learning_rate: 8.2372e-04
# Epoch 4/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1735 - val_loss: 0.1624 - learning_rate: 8.2372e-04
# Epoch 5/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1691 - val_loss: 0.1613 - learning_rate: 8.2372e-04
# Epoch 6/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1660 - val_loss: 0.1523 - learning_rate: 8.2372e-04
# Epoch 7/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1643 - val_loss: 0.1634 - learning_rate: 8.2372e-04
# Epoch 8/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1642 - val_loss: 0.1608 - learning_rate: 8.2372e-04
# Epoch 9/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1575 - val_loss: 0.1458 - learning_rate: 4.1186e-04
# Epoch 10/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1564 - val_loss: 0.1472 - learning_rate: 4.1186e-04
# Epoch 11/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1558 - val_loss: 0.1516 - learning_rate: 4.1186e-04
# Epoch 12/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1526 - val_loss: 0.1440 - learning_rate: 2.0593e-04
# Epoch 13/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1516 - val_loss: 0.1431 - learning_rate: 2.0593e-04
# Epoch 14/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1512 - val_loss: 0.1467 - learning_rate: 2.0593e-04
# Epoch 15/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1488 - val_loss: 0.1416 - learning_rate: 2.0593e-04
# Epoch 16/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1488 - val_loss: 0.1396 - learning_rate: 2.0593e-04
# Epoch 17/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1470 - val_loss: 0.1400 - learning_rate: 2.0593e-04
# Epoch 18/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1450 - val_loss: 0.1347 - learning_rate: 2.0593e-04
# Epoch 19/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1448 - val_loss: 0.1473 - learning_rate: 2.0593e-04
# Epoch 20/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1448 - val_loss: 0.1320 - learning_rate: 2.0593e-04
# Epoch 21/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1426 - val_loss: 0.1305 - learning_rate: 2.0593e-04
# Epoch 22/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1427 - val_loss: 0.1322 - learning_rate: 2.0593e-04
# Epoch 23/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1403 - val_loss: 0.1320 - learning_rate: 2.0593e-04
# Epoch 24/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1349 - val_loss: 0.1230 - learning_rate: 1.0296e-04
# Epoch 25/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1337 - val_loss: 0.1336 - learning_rate: 1.0296e-04
# Epoch 26/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1334 - val_loss: 0.1199 - learning_rate: 1.0296e-04
# Epoch 27/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1317 - val_loss: 0.1232 - learning_rate: 1.0296e-04
# Epoch 28/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1303 - val_loss: 0.1188 - learning_rate: 1.0296e-04
# Epoch 29/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1300 - val_loss: 0.1240 - learning_rate: 1.0296e-04
# Epoch 30/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1301 - val_loss: 0.1185 - learning_rate: 1.0296e-04
# Epoch 31/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1304 - val_loss: 0.1191 - learning_rate: 1.0296e-04
# Epoch 32/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1303 - val_loss: 0.1239 - learning_rate: 1.0296e-04
# Epoch 33/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1253 - val_loss: 0.1176 - learning_rate: 5.1482e-05
# Epoch 34/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1249 - val_loss: 0.1164 - learning_rate: 5.1482e-05
# Epoch 35/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1254 - val_loss: 0.1179 - learning_rate: 5.1482e-05
# Epoch 36/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1245 - val_loss: 0.1170 - learning_rate: 5.1482e-05
# Epoch 37/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1226 - val_loss: 0.1164 - learning_rate: 2.5741e-05
# Epoch 38/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1230 - val_loss: 0.1151 - learning_rate: 2.5741e-05
# Epoch 39/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1228 - val_loss: 0.1184 - learning_rate: 2.5741e-05
# Epoch 40/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1211 - val_loss: 0.1150 - learning_rate: 2.5741e-05
# Epoch 41/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1202 - val_loss: 0.1151 - learning_rate: 1.2871e-05
# Epoch 42/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1208 - val_loss: 0.1147 - learning_rate: 1.2871e-05
# Epoch 43/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1206 - val_loss: 0.1154 - learning_rate: 1.2871e-05
# Epoch 44/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1197 - val_loss: 0.1173 - learning_rate: 1.2871e-05
# Epoch 45/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1205 - val_loss: 0.1148 - learning_rate: 6.4353e-06
# Epoch 46/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1190 - val_loss: 0.1161 - learning_rate: 6.4353e-06
# Epoch 47/50
# 1094/1094 - 2s - 2ms/step - loss: 0.1195 - val_loss: 0.1152 - learning_rate: 3.2177e-06
# {
#   "metrics": {
#     "accuracy": 0.9678666666666021,
#     "precision": 0.9486301369854891,
#     "recall": 0.7241830065354744,
#     "specificity": 0.9955456570155162,
#     "f1": 0.8213491470250713,
#     "roc_auc": 0.976166402220453,
#     "n_eval": 15000,
#     "pos_rate_eval": 0.102,
#     "aic": 2870.7639019553285,
#     "bic": 3358.1754526807267,
#     "log_likelihood": -1371.3819509776642,
#     "n_features": 64,
#     "mode": "STRICT_CAUSAL",
#     "split": "RANDOM_ROW",
#     "best_params": {
#       "lr": 0.0008237189558335285,
#       "batch_size": 64,
#       "optimizer": "rmsprop",
#       "n_layers": 3,
#       "dropout_rate": 0.49554443556259786,
#       "l2": 0.0017558886158773755,
#       "activation": "gelu",
#       "units_l0": 128,
#       "units_l1": 256,
#       "units_l2": 96
#     }
#   }
# }
# confusion_matrix [tn fp fn tp]: 13410 60 422 1108
